# %% [markdown]
# This notebook contains code and output of descriptive analyses for the 2000-2017 CC dataset after cleaning

# %% [markdown]
# # Setting up the Python environment
# Ensure that the following packages have been installed using "pip install <packagename>" from the python command line before running the next chunk:
# - pandas
# - gsspread
# - oauth2client.service_account
#
# **Note: This chunk takes a while to execute.**

# %%
import gspread
import pandas as pd
from oauth2client.service_account import ServiceAccountCredentials
import numpy as np

#Magic to make plots display
import matplotlib.pyplot as plt
# %matplotlib notebook

# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('TD_client.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# Now we read the data in from Google Sheets

# %%
data = client.open("cleaned CC data 2000-2017.csv").sheet1
df=pd.DataFrame(data.get_all_records())

# %% [markdown]
# Here we remove unnecessary columns from df.

# %%
print(df.columns)
df = df[['autotomized','date','location','mass','meters','misc','new.recap','paint.mark','painted','rtl','sex','sighting','species','svl','tl','toes','vial','year']]
print(df.columns)
# Out:
# Index(['', 'autotomized', 'date', 'drop_morphometrics', 'drop_species',
#        'forceFemale', 'forceMale', 'forceNew', 'forceRecap', 'forceSighting',
#        'location', 'mass', 'meters', 'misc', 'new.recap', 'new.recap_orig',
#        'paint.mark', 'painted', 'review_new.recap', 'review_painted',
#        'review_rtl', 'review_sex', 'review_species', 'rtl', 'rtl_orig', 'sex',
#        'sighting', 'species', 'svl', 'tl', 'toes', 'vial', 'year'],
#       dtype='object')
# Index(['autotomized', 'date', 'location', 'mass', 'meters', 'misc',
#        'new.recap', 'paint.mark', 'painted', 'rtl', 'sex', 'sighting',
#        'species', 'svl', 'tl', 'toes', 'vial', 'year'],
#       dtype='object')

# %% [markdown]
# In order to plot the data, we need to force svl, tl, rtl and mass to numeric variables.

# %%
# do this more neatly
numericCols=['svl','tl','rtl','mass','meters']
for i in numericCols: df[i]=pd.to_numeric(df[i],errors='coerce')

# %% [markdown]
# The following tables exclude non-ideal values for the variables in question, but once the columns are cleaned in the source file, this won't be an issue.

# %% [markdown]
# Drop data for species other than 'j' and 'v'.

# %%
print(df.shape)
species2keep=['j','v']
df = df.loc[df.species.isin(species2keep)]
print (df.shape)
# Out:
# (8197, 18)
# (5910, 18)

# %% [markdown]
# Dropping non-ideal data for sex.

# %%
print(df.shape)
sex2keep=['m','f']
df = df.loc[df.sex.isin(sex2keep)]
print (df.shape)
# Out:
# (5910, 18)
# (2555, 18)

# %% [raw]
# Creating tl/svl and mass/svl indices

# %%
df['tl_svl']=(df.tl/df.svl)
df['mass_svl']=(df.mass/df.svl)

# %% [markdown]
# Create age_class index
#
# **NOTE:** confirm cut point for size at maturity

# %%
df['age_class']=pd.np.nan
df['age_class'].loc[(df.svl>=56)&(df.species=='j'),]='adult'
df['age_class'].loc[(df.svl<56)&(df.species=='j'),]='juvenile'
df['age_class'].loc[(df.svl>=45)&(df.species=='v'),]='adult'
df['age_class'].loc[(df.svl<45)&(df.species=='v'),]='juvenile'
# Out:
# C:\Users\Christopher\Anaconda3\lib\site-packages\pandas\core\indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# Create boolean flag to drop data from analyses

# %%
df['myDrop']= pd.np.nan
df['dropReason']= pd.np.nan

# %% [markdown]
# Populate 'myDrop' column bsed on outliers in data

# %%
df.loc[((df.svl>75)& (df.species=='v')),'myDrop']=True
df.loc[((df.svl>75)& (df.species=='v')),'dropReason']='svl;species'
df.loc[((df.species=='j')&(df.mass>40)),'myDrop']=True
df.loc[((df.species=='j')&(df.mass>40)),'dropReason']='svl;mass'
df.loc[((df.species=='v')&(df.mass>25)),'myDrop']=True
df.loc[((df.species=='v')&(df.mass>25)),'dropReason']='svl;mass'
df.loc[df.meters< -50,'myDrop']=True
df.loc[df.meters< -50,'dropReason']='meters'
df.myDrop.value_counts()
# Out:
# True    11
# Name: myDrop, dtype: int64

# %% [markdown]
# Create a dataframe of values based on myDrop==True and export to csv.

# %%
df2run=df.loc[df.myDrop!=True]
df2Check=df.loc[df.myDrop==True,]
df2Check
# Out:
#      autotomized                  date  \
# 890        FALSE  2002-07-14T00:00:00Z
# 891        FALSE  2002-07-14T00:00:00Z
# 892        FALSE  2002-07-14T00:00:00Z
# 1723       FALSE  2002-03-20T00:00:00Z
# 6154       FALSE  2012-05-25T00:00:00Z
# 6215        TRUE  2013-07-03T00:00:00Z
# 6292        TRUE  2013-07-15T00:00:00Z
# 6305        TRUE  2014-07-05T00:00:00Z
# 6306       FALSE  2014-07-07T00:00:00Z
# 7287       FALSE  2016-05-14T00:00:00Z
# 7345        TRUE  2016-05-13T00:00:00Z
#
#                                                location  mass  meters  \
# 890                                  halfway up to site  10.0  -200.0
# 891                      left downstream 100m v 1 falls  10.8  -100.0
# 892                                       90m v 1 falls  10.3   -90.0
# 1723  rt slope half way btwn 1&2tripleRs (below R ou...  70.0   320.0
# 6154                           on oak 6m left side bowl   3.5     NaN
# 6215                                   5m v bottom site  10.0   -55.0
# 6292                                   left side sb -65   5.6   -65.0
# 6305                                      in-the-sb--55  14.5   -55.0
# 6306                                          rt sb -55   4.8   -55.0
# 7287                                   left Rs opp oakR  28.0     NaN
# 7345                          left bigRpile 15m^ 2falls  55.2     NaN
#
#                                                    misc new.recap paint.mark  \
# 890                                                  NA       new      b101t
# 891                                                  NA       new      b102t
# 892                                                  NA       new      b103t
# 1723                                                 NA       new       y77a
# 6154                                                 NA       new        w3b
# 6215                                                 NA     recap        o1c
# 6292                                                 NA     recap        o.a
# 6305                                            TSS;BSS     recap       o29c
# 6306                                    B rec shed; Tss       new       o32a
# 7287                                                 NA       new       y32b
# 7345  tail angle at 10; toes 13, 19 broken; wound sc...     recap       y28b
#
#      painted   rtl     ...        svl     tl          toes  \
# 890       NA   0.0     ...       63.0   92.0     3-7-11-19
# 891       NA   0.0     ...       66.0   92.0     3-7-11-18
# 892       NA   0.0     ...       68.0  103.0     3-7-12-16
# 1723      NA   0.0     ...       61.0   86.0    4-10-14-20
# 6154     yes   0.0     ...       79.0   63.0       7-11-18
# 6215     yes  21.0     ...       69.0   53.0       5-11-15
# 6292     yes  20.0     ...       56.0   54.0        2-6-18
# 6305     yes  30.0     ...       74.0   67.0       5-11-16
# 6306     yes   0.0     ...       52.0   72.0        4-7-11
# 7287     yes   0.0     ...       45.0   57.0     3-6-15-17
# 7345     yes   0.0     ...       54.0   63.0  4-9-14-15-18
#
#                     vial  year    tl_svl  mass_svl age_class  myDrop  \
# 890   toes in vial 58-02  2002  1.460317  0.158730     adult    True
# 891   toes in vial 59-02  2002  1.393939  0.163636     adult    True
# 892   toes in vial 60-02  2002  1.514706  0.151471     adult    True
# 1723  toes in vial 32-02  2002  1.409836  1.147541     adult    True
# 6154               12-12  2012  0.797468  0.044304     adult    True
# 6215                  NA  2013  0.768116  0.144928     adult    True
# 6292                  NA  2013  0.964286  0.100000     adult    True
# 6305                  NA  2014  0.905405  0.195946     adult    True
# 6306               14-46  2014  1.384615  0.092308     adult    True
# 7287               16-50  2016  1.266667  0.622222     adult    True
# 7345                  NA  2016  1.166667  1.022222     adult    True
#
#        dropReason
# 890        meters
# 891        meters
# 892        meters
# 1723     svl;mass
# 6154  svl;species
# 6215       meters
# 6292       meters
# 6305       meters
# 6306       meters
# 7287     svl;mass
# 7345     svl;mass
#
# [11 rows x 23 columns]

# %%
df2Check.to_csv("Outliers to check(2000-2017).csv")

# %%
df.to_csv("Descriptive Analyses of CC Data (2000-2017).csv")

# %% [markdown]
# ## Summary Analyses

# %% [markdown]
# ### Tables
#
# **NOTE:**  We need to format these into laTex tables or something else that has borders.

# %%
df.loc[df.myDrop!=True].groupby(['species','sex'])['autotomized'].count()
# Out:
# species  sex
# j        f      960
#          m      803
# v        f      351
#          m      430
# Name: autotomized, dtype: int64

# %%
df.loc[df.myDrop!=True].groupby(['species','sex','autotomized'])['new.recap'].count()
# Out:
# species  sex  autotomized
# j        f    FALSE          664
#               TRUE           296
#          m    FALSE          514
#               TRUE           289
# v        f    FALSE          286
#               TRUE            65
#          m    FALSE          334
#               TRUE            96
# Name: new.recap, dtype: int64

# %% [markdown]
# **NOTE:  The plots below need to be edited to better label the axes.**

# %% [markdown]
# **NOTE** exclude outliers and rerun (include if mass_svl<0.6)

# %% [markdown]
# ## Adult lizards

# %% [markdown]
# ### S. jarrovii
# #### SVL

# %%
species=['S. jarrovii', 'S. virgatus']
print(species)
sex=['female','male']
print(sex)
# Out:
# ['S. jarrovii', 'S. virgatus']
# ['female', 'male']

# %%
dfSpecies=df2run.groupby('species')
print(dfSpecies)
# Out:
# <pandas.core.groupby.DataFrameGroupBy object at 0x0000024FA47F67F0>

# %%
df2run.age_class.unique()
# Out:
# array(['juvenile', 'adult', nan], dtype=object)

# %% [markdown]
# #subplots
# axj=df2run.loc[df2run.species=='j'].boxplot(column='svl',by=['sex','age_class'])
# axv=df2run.loc[df2run.species=='v'].boxplot(column='svl',by=['sex','age_class'])
# #big plot
# #plt.suptitle('SVL by species and age-class')
# f, (ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=True)
# # fixing labeling
# ax1.set_ylabel('SVL(mm)')
# ax1.set_title('S.jarrovii')
# ax2.set_title('S.virgatus')
# # add data
# ax1.boxplot(data=df2run.svl.groupby(['sex','age_class']))
# #aj2.boxplot()=axv
# #plt.subplot(plot_number=1,nrows==1,ncols=2,sharey=True)
# #plt.title(species[0])
# #subplots
#
# #plt.subplot(plot_number=2,nrows==1,ncols=2,sharey=True)
# #plt.title(species[1])
# #plt.ylabel('SVL(mm)')
# #plt.plot(range(12))
#
# #df.loc[df.myDrop!=True].plot.box(x='species', y='svl',use_index=False,subplots=True,sharex=False,sharey=True,layout=(1,2),table=False,title='title')

# %% [markdown]
# #big plot
# plt.plot()
# #plt.suptitle('SVL by species and age-class')
# f, (ax1,ax2)=plt.subplots(nrows=1,ncols=2,sharey=True)
# # fixing labeling
# ax1.set_ylabel('SVL(mm)')
# ax1.set_title('S. jarrovii')
#
# ax2.set_title('S. virgatus')
# # add data
# #plt.boxplot(df2run.values())
# #aj2.boxplot()=axv

# %%
jSvl=df2run.loc[df2run.species=='j'].boxplot(column='svl',by=['sex','age_class'])
jSvl.set_title(species[0])
jSvl.set_ylabel('SVL (mm)')
jSvl.set_ylim(0,110)
plt.suptitle("")
# Out:
# <div id='6eb29133-ad1a-4a85-af2d-b4b29d9f1817'></div>

# %%
vSvl=df2run.loc[df2run.species=='v'].boxplot(column='svl',by=['sex','age_class'])                                
vSvl.set_title(species[1])
vSvl.set_ylabel('SVL (mm)')
vSvl.set_ylim(0,110)
plt.suptitle("")
# Out:
# <div id='15f7ef24-99b6-4742-962b-0c9efa50d78c'></div>

# %% [markdown]
# #### TL
#
# There are some hi juveniles values here

# %%
jTL=df2run.loc[df2run.species=='j'].boxplot(column=['tl'],by=['sex', 'age_class'])
jTL.set_title(species[0])
jTL.set_ylabel('TL (mm)')
jTL.set_ylim(0,140)
plt.suptitle("")
# Out:
# <div id='509e9e84-2981-4fa4-8cef-274082060fb7'></div>

# %%
vTL=df2run.loc[df2run.species=='v'].boxplot(column=['tl'],by=['sex', 'age_class'])
vTL.set_title(species[1])
vTL.set_ylabel('TL (mm)')
vTL.set_ylim(0,140)
plt.suptitle("")
# Out:
# <div id='97bba116-52dd-4be4-9ed6-e6f6dfbadda6'></div>

# %% [markdown]
# #### mass
#
# **NOTE:** There are still some low mass Sj adults that we need to investigate

# %%
jMass=df2run.loc[df2run.species=='j'].boxplot(column=['mass'],by=['sex', 'age_class'])
jMass.set_title(species[0])
jMass.set_ylabel('Mass (g)')
jMass.set_ylim(0,35)
plt.suptitle("")
# Out:
# <div id='0518ea78-499a-49f8-8ce6-ba4e707bda4b'></div>

# %%
vMass=df2run.loc[df2run.species=='v'].boxplot(column=['mass'],by=['sex', 'age_class'])
vMass.set_title(species[1])
vMass.set_ylabel('Mass (g)')
vMass.set_ylim(0,35)
plt.suptitle("")
# Out:
# <div id='50c772fb-6f95-4c8a-9545-bdcc21757cf1'></div>

# %% [markdown]
# #### TL/SVL Ratio
# **NOTE:** There are still some low SVL/TL ratios here for adults that we need to look into

# %%
jTlSvl=df2run.loc[df2run.species=='j'].boxplot(column=['tl_svl'],by=['sex', 'age_class'])
jTlSvl.set_title(species[0])
jTlSvl.set_ylabel('TL/SVL')
jTlSvl.set_ylim(0,2.25)
plt.suptitle("")
# Out:
# <div id='34f8288e-8d0e-4ea2-abc4-823fd2f8d8fd'></div>

# %%
vTlSvl=df2run.loc[df2run.species=='v'].boxplot(column=['tl_svl'],by=['sex', 'age_class'])
vTlSvl.set_title(species[1])
vTlSvl.set_ylabel('TL/SVL')
vTlSvl.set_ylim(0,2.25)
plt.suptitle("")
# Out:
# <div id='f4a22f5f-04c7-4ccb-a3b9-addd7e48b247'></div>

# %%
jMassSvl=df2run.loc[df2run.species=='j'].boxplot(column=['mass_svl'],by=['sex', 'age_class'])
jMassSvl.set_title(species[0])
jMassSvl.set_ylabel('Mass/SVL (g/mm)')
jMassSvl.set_ylim(0,.8)
plt.suptitle("")
# Out:
# <div id='55dc0165-9382-49d9-b5f1-dc8081e47090'></div>

# %%
vMassSvl=df2run.loc[df2run.species=='v'].boxplot(column=['mass_svl'],by=['sex', 'age_class'])
vMassSvl.set_title(species[1])
vMassSvl.set_ylabel('Mass/SVL (g/mm)')
vMassSvl.set_ylim(0,.)
plt.suptitle("")
# Out:
#   File "<ipython-input-29-e59d522a0a84>", line 4
#     vMassSvl.set_ylim(0,.)
#                         ^
# SyntaxError: invalid syntax

# %%
df.loc[(df.age_class=='adult')&(df.myDrop!=True),].groupby('species').boxplot(column=['mass_svl'],by=['sex'])
df.loc[(df.age_class=='juvenile')&(df.myDrop!=True),].groupby('species').boxplot(column=['mass_svl'],by=['sex'])

# %% [markdown]
# Add groupby arguments that include species ageclass and sex for all summaries
#     - consider adding year
# Types of visualizations:
# - tables (autotomy, new/recap (1st sightings only)
# - boxplots (svl, tl, rtl, mass)
# - histograms (age class (svl), meters (location))

# %% [markdown]
# For inferential stats
# - differences:
#     - between seasons within years
#     - between years (weather and fire)
#     - population density (revist how to calculate this)
#         - ran study until flatline
#         - do we need to account for person-hours still?

# %% [markdown]
# The following histograms show the distribution of animals linearly along the site.  The x-axis is location in meters and the y axis in the number of animals.  The graphs are separated by sex and species.

# %% [markdown]
# The differences between the adults and juvenile are interesting, no?

# %% [markdown]
# Adults

# %%
#Scale the figures so that the y axes are the same
df.loc[(df.myDrop!=True)&(df.age_class=='adult')].groupby('species').hist(column='svl',by=['sex'])

# %% [markdown]
# Juveniles

# %%
df.loc[(df.myDrop!=True)&(df.age_class=='juvenile')].groupby('species').hist(column='svl',by=['sex'])

# %% [markdown]
# TL - Adults

# %%
#Standardize x and y axes
df.loc[(df.myDrop!=True)&(df.age_class=='adult')].groupby('species').hist(column='tl',by=['sex'])

# %% [markdown]
# Juveniles

# %%
df.loc[(df.myDrop!=True)&(df.age_class=='juvenile')].groupby('species').hist(column='tl',by=['sex'])

# %% [markdown]
# Overall view of tail loss
# **NOTE:** The autotomized==True argumetn is throwing an error here for some reason and rtl!=0 may exclude autotomized individuals which haven't regrown tail. Have to chase this down later

# %%
#df.loc[(df.myDrop!=True)&(df.age_class=='adult')&(df.autotomized==True)].hist(column='rtl',by=['species','sex'])
#df.loc[(df.myDrop!=True)&(df.age_class=='juvenile')&(df.autotomized==True)].hist(column='rtl',by=['species','sex'])
#df.loc[df.rtl!=0].hist(column='rtl',by=['species','sex'])

# %% [markdown]
# Adults

# %%
df.loc[((df.age_class=='adult')&(df.myDrop!=True)),].groupby('species').hist(column='tl',by=['sex'])

# %% [markdown]
# Juveniles

# %%
df.loc[(df.myDrop!=True)&(df.age_class=='juvenile')].groupby('species').hist(column='svl',by=['sex'])

# %%
df.loc[((df.myDrop!=True)&(df.age_class=='adult')),].groupby('species').hist(column='mass',by=['sex'])
