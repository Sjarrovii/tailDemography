# %% [markdown]
# # Cleaning Data (Part 1)
# The purpose of this notebook is to read in raw excel data for multiple years, rename and trim columns, append cleaned files into a single dataframe and export this dataframe as an excel file.

# %% [markdown]
# # Table of Contents
# 1. [Setting up Python](#Setting-up-Python)
#
#     1. [Setting the Location](#Setting-the-Location)
#
#     2. [Importing Necessary Packages](#Importing-Necessary-Packages)
#
#     3. [Functions](#Functions)
#
#     4. [Preparing for a Save](#Preparing-for-a-Save)
#
# 2. [Handling Columns](#Handling-Columns)
#
#     1. [Find Unique Column Names](#Find-Unique-Column-Names)
#
#     2. [Eliminate Unnecessary Columns](#Eliminate-Unnecessary-Columns)
#
#     3. [Combine Synonyms](#Combine-Synonyms)
#
# 3. [Reading and Appending Data](#Reading-and-Appending-Data)
#
# 4. [Exporting Data](#Exporting-Data)
# 5. [Where to Next](#Where-to-Next)

# %% [markdown]
# # Setting up Python
# [Top](#TOC)
#
# [Setting the Location](#SettingLoc)
#
# [Importing Necessary Packages](#ImportingPackages)
#
# [Getting Data](#GettingData)
#
# [Preparing for a Save](#PreparingSave)

# %% [markdown]
# ## Importing Necessary Packages
#
# [Top](#TOC)
#
# [Setting Up Python](#SettingUp)
#
# Here we import necessary packages.
# This chunk may take a while.

# %%
import pandas as pd
# import numpy as np
import glob,os

# increase print limit
pd.options.display.max_rows = 99999
pd.options.display.max_colwidth = 50
pd.set_option('mode.sim_interactive', True)

# %% [markdown]
# ## Functions
# [Back to: Top](#TOC)
#
# [Back to: Setting Up Python](#SettingUp)
#
# 1. [xlcolshape](#xlcolshape)
#
# 2. [xluniquecol2](#xluniquecol2)
#
# 3. [colmatchtodict](#colmatchtodict)
#
# 4. [findsyn](#findsyn)
#
# 5. [readnsplit](#readnsplit)
#
# 6. [mapndrop](#mapndrop)
#
# 7. [namefile](#namefile)

# %%
def xlcolshape(file, verbose = True):
    """xlcolshape takes a file name as a string and returns the shape of the excel file"""
    assert isinstance(verbose,bool),"'verbose' must be bool not,{}".format(type(verbose))
    dictionary = {}
    for sheet in pd.ExcelFile(file).sheet_names:
        try:
            tmp = pd.read_excel(file,sheet_name =sheet).shape
            dictentry = file+'_'+sheet
            dictionary[dictentry] = tmp
            if verbose == True:
                print("Doing stuff you asked me to do for file \'{}\',sheet \'{}\' programmer person."\
                      .format(file, sheet))            
        except:
            print("This didn't work for file {}, sheet {}".format(file, sheet))
            
    return dictionary

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def xluniquecol2(file, header = 0, verbose=True):
    tmp = []
    for sheet in pd.ExcelFile(file).sheet_names:
        if (('species' in pd.read_excel(file,sheet_name=sheet, header = header).columns)\
            or('Species' in pd.read_excel(file,sheet_name=sheet, header = header).columns)):
            try:
                tmp = list(set(tmp+list(pd.read_excel(file,sheet_name=sheet).columns)))
                if verbose==True:
                    print("Doing stuff you asked me to do for file \'{}\',sheet \'{}\' programmer person."\
                          .format(file,sheet))
                res = tmp
            except:
                print("This didn't work for file {}, sheet {}".format(file,sheet))
        else:
            print("Check columns for file {}.".format(file))
            res = None
    return res

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def colmatchtodict(x,series, dictsource, key= None):
    """This takes a string, x, and a looks for values in a series that match that contain that string.
    Those values which match are returned as values in a python dict for the key, key.""" 
    assert isinstance(series,pd.Series)
    if key is None:
        key = x
    tmp = series[series.astype(str).str.contains(x,case = False)].tolist()
    dictsource[key] = tmp
    return dictsource

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def findsyn (name,dictionary, verbose = True):
    """
    *findsyn* checks searches the values of the dict *dictionary* for the string, *name* and returns 
    the key for the key,value pair to which *name* belongs.
    """
    tmp = pd.DataFrame({'preferredcol':list(dictionary.keys()),'synonymns':list(dictionary.values())})
    try:
        res = list(tmp.preferredcol[tmp.synonymns.apply(lambda x:name in x)])[0]
    except:
        res = None
        if verbose == True:
            print("No value matching \"{}\" was found in the dictionary.".format(name))
    return res

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def readnsplit(file,newsourcefolder,dtype=None,verbose=True):
    """
    This function reads an excel file, splits its sheets into separate files and saves them to folder
    *newsourcefolder*.
    """
    suffix = '.'+file.split('.')[1]
    prefix = file[:-len(suffix)]
    for sheet in pd.ExcelFile(file).sheet_names:
        try:
            splitfile = newsourcefolder+'/'+prefix+'_'+sheet+suffix
            tmp = pd.read_excel(file,dtype=dtype, sheet_name=sheet).to_excel(splitfile,index=False)
            if verbose==True:
                print("Success!  \'{}\',sheet \'{}\' has been saved to {} and the corresponding\
                google drive file as {}.".format(file,sheet,newsourcefolder,splitfile))
            continue
        except:
            print("Unable to save \'{}\',sheet \'{}\' as a separate file.".format(file,sheet))

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def mapndrop(df,dictionary,verbose=True):
    """
    This function renames columns in *df* deemed synonymous according to a dict,
    *dictionary*, and drops unnecessary columns before returning the cleaner dataframe.
    """
    try:
        df.columns = pd.Series(df.columns).map(lambda x:dictionary[x])
        tmp = df
        if verbose==True:
            print("Successfully mapped columns for df.")
        dropidx =[None==col for col in list(tmp.columns)]
        tmp=tmp.drop(columns=df.columns[dropidx])
        if verbose==True:
            print("Successfully dropped unnecessary columns for df.")
    except:
        tmp = None
        print("Skipping mapndrop call for df.")
    return tmp

# %% [markdown]
# [Back to: Functions](#Functions)

# %%
def namefile(name, tzadjust=5,tzdirection = '-', adjprecision='minutes', filetype = 'csv'):
    """takes a filename and filetype, and adds a timestamp adjusted relative to gmt to a precision 
    and returns a string that concatenates them."""
    assert isinstance(name,str),"'name' must be of type str."
    assert isinstance(tzadjust,int),"'tzadjust' must be of type int"
    assert adjprecision in ['date','hour','minutes','seconds', 'max'], "'adjprecision' must be either \
    'date', hour','minutes','seconds', or 'max'"
    precision= {'max':None,'seconds':-7,'minutes':-9, 'hours':-14,'date':-20}
    if tzdirection== '-':
        timestamp = (pd.to_datetime('now')-pd.Timedelta(hours=tzadjust))
    else:
        timestamp = (pd.to_datetime('now')+pd.Timedelta(hours=int(tzadjust[1:])))
    timestamp = str(timestamp).replace(':','hrs',1).replace(':','min',1)
    timestamp = timestamp[:precision[adjprecision]]
    filename = name+'_' + timestamp+ '.' +filetype
    return filename

# %% [markdown]
# ## Preparing for a Save
# [Top](#TOC)
#
# [Setting up Python](#SettingUp)

# %% [markdown]
# ## Setting the Location
# [Top](#TOC)
#
# [Setting Up Python](#SettingUp)
#
# These chunks identify the locations from which we can get data and to which we can save data.

# %% [markdown]
# ### Source Data
# Raw data can be found in the following locations:

# %%
# sourceDataPers = 'C:/Users/Christopher/Google Drive/TailDemography/outputFiles'
# sourceDataBig = 'S:/Chris/TailDemography/TailDemography/Raw Data'
# sourceBlack = 'C:/Users/test/Desktop'
sourceGandolf = 'C:/Users/craga/Google Drive/TailDemography/Raw Data'

# %% [markdown]
# ### Intermediate Source Data
# Intermediate files can be found in the following locations:

# %%
# sourceInterDataPers = 'C:/Users/Christopher/Google Drive/TailDemography/Intermediate Files/Source'
# sourceinterDataBig = 'S:/Chris/TailDemography/TailDemography/Intermediate Files/Source'
# sourceBlack = 'C:/Users/test/Desktop'
sourceInterGandolf = 'C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source'

# %% [markdown]
# Now we change the working directory to the source path.

# %%
os.chdir(sourceGandolf)

# %% [markdown]
# ### Output Data
# The cleaned data will be saved to one of these locations:

# %%
# outputPers = 'C:/Users/Christopher/Google Drive/TailDemography/outputFiles'
# outputBig = 'S:/Chris/TailDemography/TailDemography/Cleaned Combined Data'
# outputBlack = 'C:/Users/test/Desktop'
outputGandolf = 'C:/Users/craga/Google Drive/TailDemography/Cleaned Combined Data'

# %% [markdown]
# ### Review files

# %%
# outputPers = 'C:/Users/Christopher/Google Drive/TailDemography/Files for review/Source files'
# reviewfolderBig = 'S:/Chris/TailDemography/TailDemography/Files for review/Source files'
reviewGandolf = 'C:/Users/craga/Google Drive/TailDemography/Files for review/Source files'

# %% [markdown]
# # Handling Columns
# [Top](#TOC)
#
# We don't have to look in the multiple-sheet file.  It's clear that we'll have to identify a common set of columns prior to combining these files.  Let's define a few functions to help us do this.
#
# We will want to do the following:
# 1. [Find Unique Column Names](#FindUniqueCol)
# 2. [Eliminate Unnecessary Columns](#DropCol)
# 3. [Combine Synonyms](#CombineCol)

# %% [markdown]
# Here we use search the source path to locate and eventually read the raw data into our notebook.

# %%
rawfiles = glob.glob('*.xls*')
rawfiles
# Out:
# ['CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',
#  'CC 2004.xlsx',
#  'CC 2015 - captures.xls',
#  'CC 2016 - captures.xls',
#  'CC 2017 Lizards - 3viii17 captures and obs.xls',
#  'xCC2005x.xls',
#  'xCC2006x.xls',
#  'xCC2007x.xls',
#  'xCC2008x.xls',
#  'xCC2009x.xls',
#  'xCC2010x.xlsx',
#  'xCC2011x.xls',
#  'xCC2012x.xls',
#  'xCC2013x.xls',
#  'xCC2014x.xlsx']

# %% [markdown]
# We'll separate these into files with single or multiple sheets.

# %%
rawfiles_ms = [rawfiles[0],rawfiles[7]]
rawfiles_ss = list(set(rawfiles)- set(rawfiles_ms))

# %% [markdown]
# The names of files with multiple sheets are now in the variable *rawfiles_ms*.

# %%
rawfiles_ms
# Out:
# ['CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',
#  'xCC2007x.xls']

# %% [markdown]
# The names of files with a single sheet are now in the variable *rawfiles_ss*.

# %%
rawfiles_ss
# Out:
# ['xCC2013x.xls',
#  'xCC2005x.xls',
#  'xCC2008x.xls',
#  'xCC2009x.xls',
#  'xCC2011x.xls',
#  'xCC2006x.xls',
#  'xCC2010x.xlsx',
#  'xCC2012x.xls',
#  'CC 2015 - captures.xls',
#  'CC 2004.xlsx',
#  'CC 2017 Lizards - 3viii17 captures and obs.xls',
#  'xCC2014x.xlsx',
#  'CC 2016 - captures.xls']

# %% [markdown]
# Now let's take a look at the number of columns in each file. We'll start with the single sheet files, since this is the easiest.  We will use the function, *xlcolshape* to make this easier.
# When we call this function on the first of the single-sheet files, we can see that it returns a tuple in the format ('number of rows', 'number of columns'). The code for *xlcolshape* can be found in [Functions](#functions).

# %%
xlcolshape(rawfiles_ss[0])
# Out:
# Doing stuff you asked me to do for file 'xCC2013x.xls',sheet 'CC 2013 data' programmer person.
# {'xCC2013x.xls_CC 2013 data': (106, 20)}

# %% [markdown]
# We will apply this function to the list of files for our inspection.

# %%
pd.Series(rawfiles).apply(lambda x: xlcolshape(x,verbose=False))
# Out:
# 0     {'CC 2000-03-modified from CC-SJ 00-03 final-m...
# 1                     {'CC 2004.xlsx_2004 ': (479, 16)}
# 2            {'CC 2015 - captures.xls_2015': (241, 19)}
# 3            {'CC 2016 - captures.xls_2016': (103, 21)}
# 4     {'CC 2017 Lizards - 3viii17 captures and obs.x...
# 5                      {'xCC2005x.xls_2005': (202, 17)}
# 6                      {'xCC2006x.xls_2006': (163, 17)}
# 7     {'xCC2007x.xls_Sheet1': (507, 16), 'xCC2007x.x...
# 8                      {'xCC2008x.xls_2008': (134, 20)}
# 9                      {'xCC2009x.xls_2009': (162, 16)}
# 10                   {'xCC2010x.xlsx_Sheet1': (99, 41)}
# 11                    {'xCC2011x.xls_Sheet1': (64, 19)}
# 12                      {'xCC2012x.xls_data': (85, 19)}
# 13             {'xCC2013x.xls_CC 2013 data': (106, 20)}
# 14                     {'xCC2014x.xlsx_2014': (97, 19)}
# dtype: object

# %% [markdown]
# ## Finding Unique Columns
# [Top](#TOC)
#
# [Handling Columns](#HandlingColumns)
#
# We'll use the function, *xluniqucol2* to extract column names and convert them to an approved set.  We'll use that function to allow us to only add unique names to a list of column names.
#
# Here is an example of how xluniquecol2 works for a file with one sheet.  You can find the code for *xluniquecol2* in [Functions](#functions).

# %%
xluniquecol2(rawfiles_ss[0],verbose=False)
# Out:
# ['SVL',
#  'TL',
#  'Location',
#  'Mark',
#  'Painted',
#  'Species',
#  'Sex',
#  'Mass',
#  'Meters',
#  'Unnamed: 17',
#  'New/Recap',
#  'Misc.',
#  'Spotted',
#  'Paint Mark',
#  'Time',
#  'Toes',
#  'Date',
#  'RTL',
#  'Unnamed: 0',
#  'Vial']

# %% [markdown]
# Here is an example of how xluniquecol2 works for a file with multiple sheets.

# %%
xluniquecol2(rawfiles_ms[0],verbose=False)
# Out:
# ['SVL',
#  'Unnamed: 16',
#  'misc',
#  'TL',
#  'paint mark',
#  'TOES',
#  'TIME',
#  'meters',
#  'species',
#  'location',
#  'RTL',
#  'date',
#  'mass',
#  'sex',
#  'painted or not',
#  'VIAL',
#  'NEW/recap']

# %% [markdown]
# Now we will create an empty set, *uniquecols2*, that will eventually contain the unique column names in all of the files.
#
# We will append the unique column names from each file to *uniquecols2*.

# %%
tmp = pd.Series(rawfiles).apply(xluniquecol2,verbose=False)
uniquecols2 = list()
for u in tmp:
    uniquecols2 = uniquecols2+u
uniquecols2 = list(set(uniquecols2))
uniquecols2
# Out:
# ['SVL',
#  1,
#  'TL',
#  'paint mark',
#  'Location',
#  '1st Capture (year)',
#  'TOES',
#  'Mark',
#  'species',
#  'Toe 1',
#  'RTL (mm)',
#  'Toe 6',
#  'Painted',
#  'Toe 11',
#  'Species',
#  'Collectors',
#  'TL (mm)',
#  'date',
#  'mass',
#  'Sex',
#  'Mass',
#  'SVL (mm)',
#  'misc/notes',
#  'Toe 5',
#  'Meters',
#  'Marked',
#  'Toe 13',
#  'Toe 20',
#  'Year',
#  'Unnamed: 17',
#  'location',
#  'painted',
#  'Toe 9',
#  'Toe 18',
#  'Unnamed: 19',
#  'New/Recap',
#  'Toe 7',
#  'NEW/recap',
#  'Unnamed: 16',
#  'mass (g)',
#  'Toe 14',
#  ' painted or not',
#  'Toe 8',
#  'TIME',
#  'Toe 2',
#  'Toe 4',
#  'Misc.',
#  'meters',
#  'Spotted',
#  'Toe 3',
#  'Tail condition (1=intact; 2=autotomized; 3=regrown)',
#  'Toe 19',
#  'Years Alive (known)',
#  'painted or not',
#  'Paint Mark',
#  'Time',
#  'misc',
#  'Toe 16',
#  'Toe 17',
#  'Toes',
#  'Date',
#  'Painted or Not',
#  'Toe 10',
#  'RTL',
#  'Unnamed: 0',
#  'Toe 15',
#  'Toe 12',
#  'Vial',
#  'sex',
#  '2015 or earlier',
#  'VIAL']

# %% [markdown]
# ## Eliminate Unnecessary Columns
# [Top](#TOC)
#
# [Cleaning Data](#CleaningData)
#
# [Handling Columns](#HandlingColumns)
#
# Now we will try to identify unnecessary columns and eliminate them. Much of this will be done manually.

# %%
keepCol = ['species', 'date', 'sex', 'svl', 'tl', 'rtl', 'mass',
       'paint.mark', 'location', 'meters', 'new.recap', 'painted', 'misc',
       'vial', 'autotomized', 'sighting', 'toes','filename']

# %%
set(pd.Series(keepCol).str.lower())-set(pd.Series(uniquecols2).str.lower())
# Out:
# {'autotomized', 'filename', 'new.recap', 'paint.mark', 'sighting'}

# %%
set(pd.Series(uniquecols2).str.lower())-set(pd.Series(keepCol).str.lower())
# Out:
# {' painted or not',
#  '1st capture (year)',
#  '2015 or earlier',
#  'collectors',
#  'mark',
#  'marked',
#  'mass (g)',
#  'misc.',
#  'misc/notes',
#  nan,
#  'new/recap',
#  'paint mark',
#  'painted or not',
#  'rtl (mm)',
#  'spotted',
#  'svl (mm)',
#  'tail condition (1=intact; 2=autotomized; 3=regrown)',
#  'time',
#  'tl (mm)',
#  'toe 1',
#  'toe 10',
#  'toe 11',
#  'toe 12',
#  'toe 13',
#  'toe 14',
#  'toe 15',
#  'toe 16',
#  'toe 17',
#  'toe 18',
#  'toe 19',
#  'toe 2',
#  'toe 20',
#  'toe 3',
#  'toe 4',
#  'toe 5',
#  'toe 6',
#  'toe 7',
#  'toe 8',
#  'toe 9',
#  'unnamed: 0',
#  'unnamed: 16',
#  'unnamed: 17',
#  'unnamed: 19',
#  'year',
#  'years alive (known)'}

# %% [markdown]
# Since data for years 2000-2003 are contained in the same Excel file we will have to treat this file differently than the others.

# %% [markdown]
# ## Combining Synonymous Columns
# [Top](#TOC)
#
# [Cleaning Data](#CleaningData)
#
# [Handling Columns](#HandlingColumns)

# %% [markdown]
# Once we have identified the columns we need to keep, we'll need to apply this list to the files as they are read into python by doing the following:
#
# We will use a function, *colmatchtodict*,  to identify potential synonyms. Here's an example of how *colmatchtodict* works.  The code for this function can be found in [Functions](#functions).

# %%
coldict = {}

# %%
colmatchtodict('toes',pd.Series(uniquecols2),coldict, key = 'toes')
# Out:
# {'toes': ['TOES', 'Toes']}

# %% [markdown]
# Now let's see what happened when we apply this funtion to our, keepCol.

# %%
coldict = {}

# %%
pd.Series(keepCol).apply(lambda x: colmatchtodict(x=x,series=pd.Series(uniquecols2),dictsource=coldict))
coldict
# Out:
# {'species': ['species', 'Species'],
#  'date': ['date', 'Date'],
#  'sex': ['Sex', 'sex'],
#  'svl': ['SVL', 'SVL (mm)'],
#  'tl': ['TL', 'RTL (mm)', 'TL (mm)', 'RTL'],
#  'rtl': ['RTL (mm)', 'RTL'],
#  'mass': ['mass', 'Mass', 'mass (g)'],
#  'paint.mark': ['paint mark', 'Paint Mark'],
#  'location': ['Location', 'location'],
#  'meters': ['Meters', 'meters'],
#  'new.recap': ['New/Recap', 'NEW/recap'],
#  'painted': ['Painted',
#   'painted',
#   ' painted or not',
#   'painted or not',
#   'Painted or Not'],
#  'misc': ['misc/notes', 'Misc.', 'misc'],
#  'vial': ['Vial', 'VIAL'],
#  'autotomized': ['Tail condition (1=intact; 2=autotomized; 3=regrown)'],
#  'sighting': [],
#  'toes': ['TOES', 'Toes'],
#  'filename': []}

# %% [markdown]
# We will manually adjust the values for 'tl' and 'filename'.

# %%
coldict['tl']=['TL (mm)', 'TL', 'tl']

# %% [markdown]
# Now we need to use this dict to relabel the columns we wish to keep.
#
# We will use the function, *findsyn* to identify potential synonymous to the columnlabels in *keepcols* among the column labels in *uniquecols2*.
#
# Here is are a few examples of how *findsyn* works.  The code can be found in [Functions](#functions).

# %%
findsyn('RTi',coldict,verbose=False)

# %%
findsyn('RTi',coldict,verbose=True)
# Out:
# No value matching "RTi" was found in the dictionary.

# %%
findsyn('RTL',coldict,verbose=True)
# Out:
# 'rtl'

# %% [markdown]
# Now we apply *findsyn* to *uniquecol* and create a column of synonyms.

# %%
uniquecols2df = pd.DataFrame({'uniquecols2':uniquecols2})
uniquecols2df['preferredcol'] = uniquecols2df.uniquecols2.apply(lambda x: findsyn(x,coldict,False))
uniquecols2df
# Out:
#                                           uniquecols2 preferredcol
# 0                                                 SVL          svl
# 1                                                   1         None
# 2                                                  TL           tl
# 3                                          paint mark   paint.mark
# 4                                            Location     location
# 5                                  1st Capture (year)         None
# 6                                                TOES         toes
# 7                                                Mark         None
# 8                                             species      species
# 9                                               Toe 1         None
# 10                                           RTL (mm)          rtl
# 11                                              Toe 6         None
# 12                                            Painted      painted
# 13                                             Toe 11         None
# 14                                            Species      species
# 15                                         Collectors         None
# 16                                            TL (mm)           tl
# 17                                               date         date
# 18                                               mass         mass
# 19                                                Sex          sex
# 20                                               Mass         mass
# 21                                           SVL (mm)          svl
# 22                                         misc/notes         misc
# 23                                              Toe 5         None
# 24                                             Meters       meters
# 25                                             Marked         None
# 26                                             Toe 13         None
# 27                                             Toe 20         None
# 28                                               Year         None
# 29                                        Unnamed: 17         None
# 30                                           location     location
# 31                                            painted      painted
# 32                                              Toe 9         None
# 33                                             Toe 18         None
# 34                                        Unnamed: 19         None
# 35                                          New/Recap    new.recap
# 36                                              Toe 7         None
# 37                                          NEW/recap    new.recap
# 38                                        Unnamed: 16         None
# 39                                           mass (g)         mass
# 40                                             Toe 14         None
# 41                                     painted or not      painted
# 42                                              Toe 8         None
# 43                                               TIME         None
# 44                                              Toe 2         None
# 45                                              Toe 4         None
# 46                                              Misc.         misc
# 47                                             meters       meters
# 48                                            Spotted         None
# 49                                              Toe 3         None
# 50  Tail condition (1=intact; 2=autotomized; 3=reg...  autotomized
# 51                                             Toe 19         None
# 52                                Years Alive (known)         None
# 53                                     painted or not      painted
# 54                                         Paint Mark   paint.mark
# 55                                               Time         None
# 56                                               misc         misc
# 57                                             Toe 16         None
# 58                                             Toe 17         None
# 59                                               Toes         toes
# 60                                               Date         date
# 61                                     Painted or Not      painted
# 62                                             Toe 10         None
# 63                                                RTL          rtl
# 64                                         Unnamed: 0         None
# 65                                             Toe 15         None
# 66                                             Toe 12         None
# 67                                               Vial         vial
# 68                                                sex          sex
# 69                                    2015 or earlier         None
# 70                                               VIAL         vial

# %% [markdown]
# Now we will turn this dataframe back into a dict so that we can easily use it to rename columns

# %%
uniquecols2df.index = uniquecols2df.uniquecols2
uniquecols2dict = pd.Series(uniquecols2df.preferredcol).to_dict()
uniquecols2dict
# Out:
# {'SVL': 'svl',
#  1: None,
#  'TL': 'tl',
#  'paint mark': 'paint.mark',
#  'Location': 'location',
#  '1st Capture (year)': None,
#  'TOES': 'toes',
#  'Mark': None,
#  'species': 'species',
#  'Toe 1': None,
#  'RTL (mm)': 'rtl',
#  'Toe 6': None,
#  'Painted': 'painted',
#  'Toe 11': None,
#  'Species': 'species',
#  'Collectors': None,
#  'TL (mm)': 'tl',
#  'date': 'date',
#  'mass': 'mass',
#  'Sex': 'sex',
#  'Mass': 'mass',
#  'SVL (mm)': 'svl',
#  'misc/notes': 'misc',
#  'Toe 5': None,
#  'Meters': 'meters',
#  'Marked': None,
#  'Toe 13': None,
#  'Toe 20': None,
#  'Year': None,
#  'Unnamed: 17': None,
#  'location': 'location',
#  'painted': 'painted',
#  'Toe 9': None,
#  'Toe 18': None,
#  'Unnamed: 19': None,
#  'New/Recap': 'new.recap',
#  'Toe 7': None,
#  'NEW/recap': 'new.recap',
#  'Unnamed: 16': None,
#  'mass (g)': 'mass',
#  'Toe 14': None,
#  ' painted or not': 'painted',
#  'Toe 8': None,
#  'TIME': None,
#  'Toe 2': None,
#  'Toe 4': None,
#  'Misc.': 'misc',
#  'meters': 'meters',
#  'Spotted': None,
#  'Toe 3': None,
#  'Tail condition (1=intact; 2=autotomized; 3=regrown)': 'autotomized',
#  'Toe 19': None,
#  'Years Alive (known)': None,
#  'painted or not': 'painted',
#  'Paint Mark': 'paint.mark',
#  'Time': None,
#  'misc': 'misc',
#  'Toe 16': None,
#  'Toe 17': None,
#  'Toes': 'toes',
#  'Date': 'date',
#  'Painted or Not': 'painted',
#  'Toe 10': None,
#  'RTL': 'rtl',
#  'Unnamed: 0': None,
#  'Toe 15': None,
#  'Toe 12': None,
#  'Vial': 'vial',
#  'sex': 'sex',
#  '2015 or earlier': None,
#  'VIAL': 'vial'}

# %% [markdown]
# We'll use the dict, *uniquecols2dict* to rename the synonymous columns in our file....once we read them in,
# that is.

# %% [markdown]
# # Reading and Appending Data
# [Top](#TOC)

# %% [markdown]
# Now we use the function *readnsplit* to actually read in the source files, drop unnecessary columns and renaming columns according to a dictionary.
#
# Here is an example of how *readnsplit* works.  The code can be found in [Functions](#functions).

# %%
readnsplit(rawfiles[0],sourceInterGandolf,str)
# Out:
# Success!  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',sheet '2000' has been saved to C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source and the corresponding                google drive file as C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source/CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2000.xlsx.
# Success!  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',sheet '2001' has been saved to C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source and the corresponding                google drive file as C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source/CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2001.xlsx.
# Success!  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',sheet '2002' has been saved to C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source and the corresponding                google drive file as C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source/CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2002.xlsx.
# Success!  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19.xlsx',sheet '2003' has been saved to C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source and the corresponding                google drive file as C:/Users/craga/Google Drive/TailDemography/Intermediate Files/Source/CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2003.xlsx.

# %%
for file in rawfiles:
    readnsplit(file,sourceInterGandolf,dtype=str, verbose=False)

# %% [markdown]
# We need to change the directory to the location where the intermediate files this operates on can be found.  We will also save a list of the files names in that location for convenience.

# %%
os.chdir(sourceInterGandolf)
splitfiles = glob.glob('*xls*')
splitfiles
# Out:
# ['CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2000.xlsx',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2001.xlsx',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2002.xlsx',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2003.xlsx',
#  'CC 2004_2004 .xlsx',
#  'CC 2015 - captures_2015.xls',
#  'CC 2016 - captures_2016.xls',
#  'CC 2017 Lizards - 3viii17 captures and obs_2017.xls',
#  'xCC2005x_2005.xls',
#  'xCC2006x_2006.xls',
#  'xCC2007x_2007.xls',
#  'xCC2007x_Sheet1.xls',
#  'xCC2008x_2008.xls',
#  'xCC2009x_2009.xls',
#  'xCC2010x_Sheet1.xlsx',
#  'xCC2011x_Sheet1.xls',
#  'xCC2012x_data.xls',
#  'xCC2013x_CC 2013 data.xls',
#  'xCC2014x_2014.xlsx']

# %% [markdown]
# Now we remove 'xCC2007x_Sheet1.xls' from the list of files we will process intermediate files since this is a subset of the 'xCC2007x_2007.xls' reordered and with some columns dropped.

# %%
splitfiles = list(set(splitfiles)-set(['xCC2007x_Sheet1.xls']))
splitfiles
# Out:
# ['CC 2015 - captures_2015.xls',
#  'xCC2007x_2007.xls',
#  'xCC2014x_2014.xlsx',
#  'CC 2004_2004 .xlsx',
#  'xCC2006x_2006.xls',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2002.xlsx',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2003.xlsx',
#  'xCC2013x_CC 2013 data.xls',
#  'xCC2009x_2009.xls',
#  'xCC2012x_data.xls',
#  'xCC2010x_Sheet1.xlsx',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2001.xlsx',
#  'CC 2017 Lizards - 3viii17 captures and obs_2017.xls',
#  'CC 2000-03-modified from CC-SJ 00-03 final-modified w headers-3Jan19_2000.xlsx',
#  'xCC2011x_Sheet1.xls',
#  'CC 2016 - captures_2016.xls',
#  'xCC2005x_2005.xls',
#  'xCC2008x_2008.xls']

# %% [markdown]
# Now we use the function *mapndrop* to drop unnecessary columns and renaming columns according to a dictionary.
#
# Here are a few examples of how *mapndrop* works.  The code can be found in [Functions](#functions).

# %%
mapndrop(df=pd.read_excel(splitfiles[0],dtype=str),dictionary=uniquecols2dict,verbose = True)
# Out:
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
#     species           toes                 date  sex  svl   tl  rtl  mass  \
# 0         j         5-7-13  2015-07-06 00:00:00    f   67   97    0   9.7
# 1         j      5-7-14-20  2015-07-06 00:00:00    m   73   71   33  14.3
# 2         j      5-7-13-16  2015-07-06 00:00:00    m   78   75   55  14.8
# 3         j           5-11  2015-07-06 00:00:00    f   75   50   15  11.3
# 4         j      5-7-13-17  2015-07-06 00:00:00    f   66   84    0    10
# 5         j      5-7-14-19  2015-07-06 00:00:00    m   78   94   24    16
# 6         j        5-15-16  2015-07-06 00:00:00    f   70   93    0  11.3
# 7         j      5-7-13-18  2015-07-06 00:00:00    f   66   88    0   9.2
# 8         j      5-7-13-19  2015-07-06 00:00:00    f   72   97    0  12.8
# 9         j      5-7-13-20  2015-07-06 00:00:00    m   73   76    4  12.5
# 10        j         5-7-14  2015-07-06 00:00:00    f   67   89    0  10.6
# 11        j        5-12-16  2015-07-06 00:00:00    m   88  126    0  24.2
# 12        j        5-12-20  2015-07-06 00:00:00    f   76  102    0  14.5
# 13        j      5-7-14-16  2015-07-06 00:00:00    f   75   98    0  14.8
# 14       uo           3-16  2015-07-06 00:00:00    f   48   61    0   3.8
# 15        v         4-9-15  2015-07-06 00:00:00    f   54   68    0   5.4
# 16        v         4-7-11  2015-07-06 00:00:00    m   56   51   20   6.5
# 17        v      4-9-15-16  2015-07-06 00:00:00    f   55   51   27   5.5
# 139       j      5-8-15-16  2015-07-20 00:00:00    f   44   60    0   2.8
# 140       v       10-11-19  2015-07-20 00:00:00    m   55   74    0   5.5
# 141       v      3-6-11-20  2015-07-20 00:00:00    m   50   68    0     4
# 142       v       10-13-20  2015-07-20 00:00:00    m   54   73    0   5.4
# 143       j      5-9-11-20  2015-07-21 00:00:00    f   42   58    0   2.3
# 144       j      5-9-12-16  2015-07-21 00:00:00    m   44   61    0   2.8
# 145       j         5-6-17  2015-07-23 00:00:00    f   76  102    0    12
# 146       v     4-10-15-20  2015-07-23 00:00:00    m   49   67    0   4.4
# 147     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 148     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 149     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 150     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 151     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 152     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 153     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 154     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 155     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 156     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 157     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 158     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 159     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 160     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 161     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 162     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 163     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 164     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 165     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 166     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 167     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 168     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 169     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 170     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 171     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 172     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 173     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 174     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 175     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 176     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 177     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 178     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 179     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 180     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 181     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 182     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 183     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 184     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 185     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 186     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 187     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 188     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 189     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 190     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 191     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 192     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 193     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 194     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 195     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 196     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 197     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 198     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 199     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 200     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 201     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 202     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 203     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 204     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 205     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 206     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 207     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 208     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 209     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 210     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 211     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 212     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 213     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 214     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 215     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 216     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 217     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 218     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 219     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 220     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 221     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 222     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 223     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 224     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 225     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 226     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 227     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 228     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 229     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 230     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 231     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 232     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 233     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 234     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 235     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 236     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 237     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 238     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 239     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
# 240     NaN            NaN                  NaN  NaN  NaN  NaN  NaN   NaN
#
#           paint.mark                                       location meters  \
# 0                w2a                              L 5m^ bottom site    -35
# 1               w21a                                          SB 5m    -25
# 2                w3a                                  SB 8m v bowl     -16
# 3                w6a                                 L SB^ 1 falls       1
# 4              w7a.c                                   SB 20^1falls     20
# 5               w20a               bottom curved wall v cave trail      35
# 6              w8a.c        top L rock [stacked] wall ^ cave trail      80
# 7                w9a           bottom rock wall^ RW at juniper xing     83
# 8             w10a.t                           SB5m below root xing    153
# 9                w11                       rock wall -> black rock     171
# 10              w14a                                  slab op slab     263
# 11              w13a                                           slab    263
# 12              w18a                                           slab    263
# 13              w15a                               LRs 3m ^ 2 falls    398
# 14               w.b                                  1 black rock     171
# 15               w1c                                      sb at -40    -40
# 16             w2c|t                                         SB -30    -30
# 17               w3c                    stream bed at juniper xing     113
# 18               w5c                                   bottom scree    321
# 19               o+b                          left R 20m v top site    435
# 20              w23a                                      Ropp oakR    420
# 21              w24a                               rt sb 10m ^ oakR    430
# 22              w29a                                      mid scree    330
# 23              w28a                        rocks opp & 5m v pineR     405
# 24             w.a.c                                  sb 20m ^ oakR    440
# 25              w10c                                    bottom site    -30
# 26               w8c                             sb 5m v cave trail     45
# 27              w30a                  Routcrop lft 5m v L at CC/CCC    240
# 28              w31a                                     top CC/CCC    245
# 29              w32a                                           slab    263
# 30              w33a                                   wall v scree    310
# 31              w36a                         left Rwall 5m^2tripleR    345
# 32              w34a                                         2falls    395
# 33               w+c                        rt sb 5m v juniper xing    108
# 34               w|a                                  sb 1m^lizardR    134
# 35               w-a                                sb 3m^L at slab    266
# 36               w-b                                    1st tripleR    304
# 37               w-c                                    1st tripleR    304
# 38               o+a                                    1st tripleR    304
# 39               w|b                              [sb ~5m v CC/CCC]  [240]
# 40              w19c                       R in sb 5m v curved wall     30
# 41              w11c                         sb opp top curved wall     50
# 42              w12c                                      sb 3m^CCC    248
# 43              w13c                                  bottom chute     358
# 44              w14c                                  sb v pyramidR    380
# 45              w15c                                    R opp pineR    410
# 46              w40q                                    top 2 falls    395
# 47               w.c                                sb juniper xing    113
# 48               w=c                              left cc at cc/ccc    250
# 49              w21c                         left stacked wall @ 78     78
# 50                .t                  rocks left below down juniper    220
# 51              w22c                              first triple rock    304
# 52              w41a                     wall v wall v juniper xing     83
# 53            w42a|t                                           slab    263
# 54              w||c  left sb opp bottom wall v wall v juniper xing     83
# 55              w.ab                                     top island    158
# 56              w|bc                                     sb at H4.5    194
# 57              w33c                                 sb L at CC/CCC    240
# 58              w28c                                         CC/CCC    245
# 59              w29c                                 bottom pyramid    380
# 60              w31c                             Rwall opp pyramidR    380
# 61              w43a                                         1falls      0
# 62              w44a                   top curved wall v cave trail     40
# 63              w.bc                      left sb 2m ^ juniper xing    115
# 64             w..ab                                    L at cc/ccc    239
# 65              w36c                                    bottom site    -40
# 66            w37c.t                     left wall 10m^juniper xing    122
# 67            w38c.t                         sb left side 5m ^ slab    268
# 68              w40c                                   sb 5m v pool    383
# 69              w39c                            top site rt side sb    455
# 70            w41c.t                                             sb    253
# 71             w..ac                 sb left side juniper ^ rt xing    166
# 72              w:ab                             sb at juniper xing    113
# 73               w.a                                             sb    -40
# 74               w.b                                       Lwall sb    -30
# 75               w.c                                             sb     54
# 76               w-a                                  L Rwall at 80     80
# 77               w-b                                    lft side sb    110
# 78               w|c                                    1m up Lwall    145
# 79              w..a                                           R sb    156
# 80              w||t                                    L at cc/ccc    239
# 81              w..b                                             sb    240
# 82              w..c                                             sb    277
# 83               w:a                                             sb    305
# 84               w:b                                           R sb    336
# 85               w^a                                             sb    380
# 86               w^b                                  R 1m ^ 2falls    396
# 87               w=b                         R lft sb base pyramidR    405
# 88               w^c                                  sb 3m ^ pineR    413
# 89               wvb                                   sb opp pineR    415
# 90               wva                                L sb 5m ^ 1oakR    425
# 91             wvc.t                                        left sb     19
# 92               w+a                                             sb     30
# 93               w+b                                           L sb    100
# 94              wxxa                                      top chute    369
# 95              w51c                               mid stacked wall     76
# 96               wxb                                          Rs sb    143
# 97               wxc                                       pancakeR    212
# 98               w>a                                  sb top island    150
# 99               w>b                                             sb    455
# 100            w=a.t                                      top chute    368
# 101             w30c                                            NaN    NaN
# 102              w1a                              L 5m^ bottom site    -35
# 103              w4a                              bottom bowl L^1m      -8
# 104              w5a                 3 m R base of juniper 1 falls       0
# 105              w12                                             H3    180
# 106             w19a                                             H4    190
# 107             w17a                                slab at s curve    272
# 108             w16a                                      mid chute    365
# 109              w4c                                          scree    322
# 110           w22a|t                                       R rt sb     -20
# 111             w26a                                    L at CC/CCC    239
# 31        new        yes         wound left shoulder dorsum; not on ventrum
# 32        new        yes                                           rec shed
# 33        new        yes                                             gravid
# 34        new        yes                         blue belly and blue throat
# 35        new        yes                                    no throat color
# 36        new        yes                                        blue throat
# 37        new        yes                                      yellow throat
# 38        new        yes                blue throat, B rec shed; T shedding
# 39        new        yes              gravid, orange throat, no belly color
# 40        new        yes                                         blue badge
# 41        new        yes                                                NaN
# 42        new        yes                                         blue badge
# 43        new        yes                                                NaN
# 44        new        yes                                         blue badge
# 45        new        yes                badge-blue dot surrounded by orange
# 46        new        yes                                    T shed rec; Bss
# 47        new        yes                                                NaN
# 48        new        yes                                                NaN
# 49        new        yes                                                NaN
# 50        new        yes                                                NaN
# 51        new        yes                                                NaN
# 52        new        yes                                    B rec shed, Tss
# 53        new        yes                 rec shed; wound rt scapular region
# 54        new        yes                           no color throat or belly
# 55        new        yes                                                NaN
# 56        new        yes                                                NaN
# 57        new        yes                                                NaN
# 58        new        yes                        blue badge w hint of orange
# 59        new        yes                                                NaN
# 60        new        yes                                   light blue badge
# 61        new        yes                                                NaN
# 62        new        yes                                    T rec shed, Bss
# 63        new        yes                        light blue throat and belly
# 64        new        yes          blue-green (turquoise) throat, blue belly
# 65        new        yes                     light orange, light blue badge
# 66        new        yes                                    T rec shed, Bss
# 67        new        yes                        Bss, T rec shed; blue badge
# 68        new        yes                                                NaN
# 69        new        yes  blue badge hint orange; lost toe 16 (not in vial)
# 70        new        yes                blue badge; just shed, loose scales
# 71        new        yes                                light orange throat
# 72        new        yes                         lt blue throat, blue belly
# 73        new        yes                                                NaN
# 74        new        yes                 T shedding; poop collected as well
# 75        new        yes                                                NaN
# 76        new        yes                                                NaN
# 77        new        yes                                                NaN
# 78        new        yes                                                Tss
# 79        new        yes                                                NaN
# 80        new        yes                                                NaN
# 81        new        yes                                                NaN
# 82        new        yes                                                NaN
# 83        new        yes            Tshedding, Bss; am unsure of paint mark
# 84        new        yes                                                NaN
# 85        new        yes                                                NaN
# 86        new        yes                                 B shedding, T shed
# 87        new        yes                                                NaN
# 88        new        yes                scar lower dorsum just above pelvis
# 89        new        yes                                    T rec shed, Bss
# 90        new        yes                                                NaN
# 91        new        yes                                    Bss, T rec shed
# 92        new        yes                                                NaN
# 93        new        yes                                                Bss
# 94        new        yes                                                NaN
# 95        new        yes                                         blue badge
# 96        new        yes                                    Bss, T rec shed
# 97        new        yes                                                NaN
# 98        new        yes                                        T shed; BSS
# 99        new        yes  toes 13.14.15 wounded; bone, tendon and claw p...
# 100      new         yes                                                NaN
# 101      new?        yes  toes 13 & 14 appear natural loss; no new toes ...
# 102     recap        yes                                o29c; still visible
# 103     recap        yes                                           BSS; TSS
# 104     recap        yes                                                NaN
# 105     recap        yes  displaying to w19a; marked w46c instead of w46...
# 106     recap        yes                                                NaN
# 107     recap        yes                            Trec ched, Bss/shedding
# 108     recap        yes                               wound lower left jaw
# 109     recap        yes                                                NaN
# 110     recap        yes                                           Bss; Tss
# 111     recap        yes                            just shed, loose scales
# 112     recap        yes                                      recently shed
# 113     recap        yes                       o45c still visible from 2014
# 114     recap        yes                                                NaN
# 115     recap        yes                either toe 10 or 11 is natural loss
# 116     recap        yes  B rec shed; H&Tss/shedding; orange paint mark ...
# 117     recap        yes                                                NaN
# 118     recap        yes                                           Bss; Tss
# 119     recap        yes                                  wound lft scapula
# 120     recap        yes                    badge-blue surrounded by orange
# 121     recap        yes  dirt on face and belly; most likely dropped la...
# 122     recap        NaN                                                NaN
# 123     recap        yes                                                NaN
# 124     recap        yes                                                NaN
# 125     recap        yes                                light yellow throat
# 126     recap        yes                                   light blue badge
# 127     recap        yes                   freckles, blue badge, B rec shed
# 128     recap        yes                        freckles (spots on ventrum)
# 129     recap        yes                        blue badge w hint of orange
# 130     recap        yes                                                NaN
# 131     recap        yes                               orange yellow throat
# 132     recap        yes                                                NaN
# 133     recap        yes  blue throat; double tail-original 3mm, regrown...
# 134     recap        yes                                   wounds on throat
# 135     recap        yes  shedding T and lower B; unreadable initially, ...
# 136     recap  repainted  should have painted "w20a"; shed since last ca...
# 137     recap        yes                                                NaN
# 138     recap        yes                                           Tss, Bss
# 139     recap        yes  toe 16 may be natural loss; toes 6&16 have fle...
# 140     recap  repainted     Brec shed, T shedding, loose scales; repainted
# 141     recap  repainted                   partially shed, Bshed, T not yet
# 142     recap        yes                                                NaN
# 143     recap        yes                                    T rec shed, Bss
# 144     recap        yes                                           Tss, Bss
# 145     recap        yes        wound left pelvis; B rec shed; loose scales
# 146     recap  repainted                            shed since last capture
# 147       NaN        NaN                                                NaN
# 148       NaN        NaN                                                NaN
# 149       NaN        NaN                                                NaN
# 150       NaN        NaN                                                NaN
# 151       NaN        NaN                                                NaN
# 152       NaN        NaN                                                NaN
# 153       NaN        NaN                                                NaN
# 154       NaN        NaN                                                NaN
# 155       NaN        NaN                                                NaN
# 156       NaN        NaN                                                NaN
# 157       NaN        NaN                                                NaN
# 158       NaN        NaN                                                NaN
# 159       NaN        NaN                                                NaN
# 160       NaN        NaN                                                NaN
# 161       NaN        NaN                                                NaN
# 162       NaN        NaN                                                NaN
# 163       NaN        NaN                                                NaN
# 164       NaN        NaN                                                NaN
# 165       NaN        NaN                                                NaN
# 166       NaN        NaN                                                NaN
# 167       NaN        NaN                                                NaN
# 168       NaN        NaN                                                NaN
# 169       NaN        NaN                                                NaN
# 170       NaN        NaN                                                NaN
# 171       NaN        NaN                                                NaN
# 172       NaN        NaN                                                NaN
# 173       NaN        NaN                                                NaN
# 174       NaN        NaN                                                NaN
# 175       NaN        NaN                                                NaN
# 176       NaN        NaN                                                NaN
# 177       NaN        NaN                                                NaN
# 178       NaN        NaN                                                NaN
# 179       NaN        NaN                                                NaN
# 180       NaN        NaN                                                NaN
# 181       NaN        NaN                                                NaN
# 182       NaN        NaN                                                NaN
# 183       NaN        NaN                                                NaN
# 184       NaN        NaN                                                NaN
# 185       NaN        NaN                                                NaN
# 186       NaN        NaN                                                NaN
# 187       NaN        NaN                                                NaN
# 188       NaN        NaN                                                NaN
# 189       NaN        NaN                                                NaN
# 190       NaN        NaN                                                NaN
# 191       NaN        NaN                                                NaN
# 192       NaN        NaN                                                NaN
# 193       NaN        NaN                                                NaN
# 194       NaN        NaN                                                NaN
# 195       NaN        NaN                                                NaN
# 196       NaN        NaN                                                NaN
# 197       NaN        NaN                                                NaN
# 198       NaN        NaN                                                NaN
# 199       NaN        NaN                                                NaN
# 200       NaN        NaN                                                NaN
# 201       NaN        NaN                                                NaN
# 202       NaN        NaN                                                NaN
# 203       NaN        NaN                                                NaN
# 204       NaN        NaN                                                NaN
# 205       NaN        NaN                                                NaN
# 206       NaN        NaN                                                NaN
# 207       NaN        NaN                                                NaN
# 208       NaN        NaN                                                NaN
# 209       NaN        NaN                                                NaN
# 210       NaN        NaN                                                NaN
# 211       NaN        NaN                                                NaN
# 212       NaN        NaN                                                NaN
# 213       NaN        NaN                                                NaN
# 214       NaN        NaN                                                NaN
# 215       NaN        NaN                                                NaN
# 216       NaN        NaN                                                NaN
# 217       NaN        NaN                                                NaN
# 218       NaN        NaN                                                NaN
# 219       NaN        NaN                                                NaN
# 220       NaN        NaN                                                NaN
# 221       NaN        NaN                                                NaN
# 222       NaN        NaN                                                NaN
# 223       NaN        NaN                                                NaN
# 224       NaN        NaN                                                NaN
# 225       NaN        NaN                                                NaN
# 226       NaN        NaN                                                NaN
# 227       NaN        NaN                                                NaN
# 228       NaN        NaN                                                NaN
# 229       NaN        NaN                                                NaN
# 230       NaN        NaN                                                NaN
# 231       NaN        NaN                                                NaN
# 232       NaN        NaN                                                NaN
# 233       NaN        NaN                                                NaN
# 234       NaN        NaN                                                NaN
# 235       NaN        NaN                                                NaN
# 236       NaN        NaN                                                NaN
# 237       NaN        NaN                                                NaN
# 238       NaN        NaN                                                NaN
# 239       NaN        NaN                                                NaN
# 240       NaN        NaN                                                NaN
#
#                     vial
# 0                  15-02
# 1                  15-16
# 2                  15-03
# 3                    NaN
# 4                  15-04
# 5                  15-15
# 6                    NaN
# 7                  15-05
# 8                  15-75
# 9                    NaN
# 10                 15-14
# 11                 15-96
# 12                 15-80
# 13                 15-84
# 14                 15-08
# 15                 15-01
# 16                   NaN
# 17                 15-06
# 18                 15-13
# 19                 15-21
# 20                 15-95
# 21                15-100
# 22                 15-83
# 23                 15-85
# 24                 15-19
# 25                 15-23
# 26                 15-22
# 27                 15-10
# 28                 15-30
# 29                 15-79
# 30                 15-12
# 31                 15-18
# 32                15-102
# 33                 15-39
# 34                 15-26
# 35                 15-31
# 36                 15-32
# 37                 15-33
# 38                 15-34
# 39                 15-27
# 40                 15-40
# 41                 15-25
# 42                 15-28
# 43                 15-36
# 44                 15-37
# 45                 15-38
# 46                 15-77
# 47                 15-42
# 48                 15-44
# 49                 15-41
# 50                 15-43
# 51                 15-45
# 52                 15-46
# 53                 15-35
# 54                 15-49
# 55                 15-54
# 56                 15-53
# 57                 15-52
# 58                 15-47
# 59                 15-48
# 60                 15-50
# 61                 15-56
# 62                 15-60
# 63                 15-61
# 64                 15-62
# 65                 15-55
# 66                 15-57
# 67                 15-58
# 68                 15-64
# 69                 15-59
# 70                 15-65
# 71                 15-66
# 72                 15-67
# 73                 15-68
# 74          15-69; 15-70
# 75                 15-71
# 76                 15-72
# 77                 15-73
# 78                 15-74
# 79                 15-09
# 80                 15-29
# 81                 15-63
# 82                 15-81
# 83                 15-82
# 84                 15-86
# 85                 15-17
# 86                 15-78
# 87                 15-87
# 88                 15-88
# 89                 15-89
# 90                 15-97
# 91                 15-91
# 92                 15-92
# 93                 15-94
# 94                 15-90
# 95                 15-93
# 96   15-98; 15-99 (poop)
# 97                 15-76
# 98                 15-07
# 99                15-101
# 100                15-11
# 101                  NaN
# 102                  NaN
# 103                  NaN
# 104                  NaN
# 105                  NaN
# 106                  NaN
# 107                  NaN
# 108                  NaN
# 109                  NaN
# 110                  NaN
# 111                  NaN
# 112                  NaN
# 113                  NaN
# 114                  NaN
# 115                  NaN
# 116                  NaN
# 117                  NaN
# 118                  NaN
# 119                  NaN
# 120                  NaN
# 121                  NaN
# 122                  NaN
# 123                  NaN
# 124                  NaN
# 125                  NaN
# 126                  NaN
# 127                  NaN
# 128                  NaN
# 129                  NaN
# 130                  NaN
# 131                  NaN
# 132                  NaN
# 133                  NaN
# 134                  NaN
# 135                  NaN
# 136                  NaN
# 137                  NaN
# 138                  NaN
# 139                  NaN
# 140                  NaN
# 141                  NaN
# 142                  NaN
# 143                  NaN
# 144                  NaN
# 145                  NaN
# 146                  NaN
# 147                  NaN
# 148                  NaN
# 149                  NaN
# 150                  NaN
# 151                  NaN
# 152                  NaN
# 153                  NaN
# 154                  NaN
# 155                  NaN
# 156                  NaN
# 157                  NaN
# 158                  NaN
# 159                  NaN
# 160                  NaN
# 161                  NaN
# 162                  NaN
# 163                  NaN
# 164                  NaN
# 165                  NaN
# 166                  NaN
# 167                  NaN
# 168                  NaN
# 169                  NaN
# 170                  NaN
# 171                  NaN
# 172                  NaN
# 173                  NaN
# 174                  NaN
# 175                  NaN
# 176                  NaN
# 177                  NaN
# 178                  NaN
# 179                  NaN
# 180                  NaN
# 181                  NaN
# 182                  NaN
# 183                  NaN
# 184                  NaN
# 185                  NaN
# 186                  NaN
# 187                  NaN
# 188                  NaN
# 189                  NaN
# 190                  NaN
# 191                  NaN
# 192                  NaN
# 193                  NaN
# 194                  NaN
# 195                  NaN
# 196                  NaN
# 197                  NaN
# 198                  NaN
# 199                  NaN
# 200                  NaN
# 201                  NaN
# 202                  NaN
# 203                  NaN
# 204                  NaN
# 205                  NaN
# 206                  NaN
# 207                  NaN
# 208                  NaN
# 209                  NaN
# 210                  NaN
# 211                  NaN
# 212                  NaN
# 213                  NaN
# 214                  NaN
# 215                  NaN
# 216                  NaN
# 217                  NaN
# 218                  NaN
# 219                  NaN
# 220                  NaN
# 221                  NaN
# 222                  NaN
# 223                  NaN
# 224                  NaN
# 225                  NaN
# 226                  NaN
# 227                  NaN
# 228                  NaN
# 229                  NaN
# 230                  NaN
# 231                  NaN
# 232                  NaN
# 233                  NaN
# 234                  NaN
# 235                  NaN
# 236                  NaN
# 237                  NaN
# 238                  NaN
# 239                  NaN
# 240                  NaN

# %%
mapndrop(df=pd.read_excel(splitfiles[4],dtype=str),dictionary=uniquecols2dict, verbose=True)
# Out:
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 152      uo           6 19  2006-05-23 00:00:00    m   49   68   26   3.5
# 153      sv          6 7 9  2006-05-30 00:00:00    m   51   64    0   3.8
# 154      sv        8 11 19  2006-05-30 00:00:00    f   48   60    0   3.9
# 155      sv        9 11 19  2006-06-08 00:00:00    f   57   49   -1   5.4
# 156      sv           9 12  2006-06-08 00:00:00    f   61   44   30   7.8
# 157      sv        5 15 18  2006-05-20 00:00:00    f   58   73    0     7
# 158      uo             13  2006-06-05 00:00:00    m   50   82    0   3.2
# 159      sv        1 10 20  2006-06-05 00:00:00    f   56   70    0   6.5
# 160      sj      4 8 11 20  2006-06-05 00:00:00    m   61   85    0   6.8
# 161      sv        5 13 20  2006-06-05 00:00:00    m   52   56    0   4.3
# 162      sv        5 16 18  2006-06-06 00:00:00  NaN  NaN  NaN  NaN   NaN
#
#     paint.mark                                           location meters  \
# 0          w4c                                            1 falls      0
# 1          ???                     juniper left side 8m v top CCC    240
# 2         w.bc                                           opp H4.5    200
# 3          w.c                                          L@ CC/CCC    240
# 4         w.at                            right juniper at CC/CCC    237
# 5          w.a  downed oak 5m ^ 2 triple R rt side [below not ...    330
# 6          w1t                                left sb 5m v 1falls     -5
# 7          w2b                                left sb 5m v 1falls     -5
# 8          w5b                             4m v 1 falls left side     -4
# 9        w6b.c                         sb wall left 20m ^ 1 falls     20
# 10      w10b.t                                      Rs rt side H3    177
# 11        w13b                             left side sb @ s-curve    280
# 12        w15b                           1m v Pyramid R left side    372
# 13        w17b                                            rt pool    380
# 14        w18b                    R outcrop left side 2m v Pine R    406
# 15        w20b                         large R rt side 8m ^ oak R    426
# 16        w22b                                             2falls    390
# 17        w23b                                          top chute    362
# 18        w25b                    sb between chute and 2 triple R    345
# 19        w28b           4m ^ rt side 10m ^ bottom site v 1 falls    -35
# 20        w30b                               left sb ~10m^1 falls     10
# 21        w31b                             R sb ~15m ^ cave trail     60
# 22        w32b                                  R sb opp lizard R    133
# 23        w34b                                      H3/H4 2.5m up    185
# 24        w36b                                      slab v talus     321
# 25        w38b                                               slab    262
# 26        w39b                                 Lwall ~15m^ 1falls     15
# 27        w41b                                    Lwall 3m v pool    377
# 28        w44b                                    R at top 2falls    390
# 29        w45b                                         sb at oakR    418
# 30        w47b  Rs opp stacked wall v wall v juniper xing [not...     85
# 31        w49b                                       plug at pool    380
# 32      w50a-b             5m ^bottom site in dead oak on rt side    -40
# 33        w53b                                       10m ^ CC/CCC    250
# 34        w54b                                           pyramidR    373
# 35        w56b                             left Rwall 5m ^ 1falls      5
# 36        w59b                            L 3m v stump on left sb    361
# 37        w65b                           R mid wall v cave trail      35
# 38        w58b                                        flatR in sb    208
# 39        w22a                                       wall v talus    314
# 40        w.a                  Lsb opp bottom R wall v cave trail     30
# 41         w.c                                 L juniper @ cc/ccc    237
# 42        w.ab                                  Pine opp Lizard R    133
# 43        w.ac                                    Rs 2m v cave tr     43
# 44        w.bc                               3m v T at top island    155
# 45         w+a                            base juniper 5m ^ flatR    213
# 46         w+c                                          Rs opp H6    202
# 47         w3b                       sb base rt wall v cave trail     30
# 48         w5a                     4m v top R wall opp cave trail     41
# 49         w9a                                   Rs sb 8m ^ oak R    426
# 50        w12a                     left opp R wall v juniper xing    102
# 51         w-a                   T opp middle wall v juniper xing    102
# 52        w27a                 2m up right side from bottom chute    355
# 53        w13a                                  Rs opp cave trail     45
# 54        w14a                               left sb ~10m^1 falls     10
# 55        w16a                             rt R wall ^ 2 Triple R    345
# 56        w40a                                    Rs 2m v cave tr     43
# 57         w-b                                 Rs sb@juniper xing    115
# 58        w24a                                          Rs opp H4    194
# 59        w25a                       R mid sb btwn rt xing and H3    168
# 60        w26a                              Rs left sb 4m v 2oakR    441
# 61        w28a                                   big R 1m v stump    363
# 62        w32a                                       10m ^ CC/CCC    250
# 63        w33a                               Rs left side oppH4.5    200
# 64        w34a                               Rs left side oppH4.5    200
# 65        w37a                          L in right sb 2m ^ bottom    -43
# 66         w-c                                     blackR 5m v H3    172
# 67        w42a                                   top stacked wall     70
# 68        w43a                      Rs opp midwall v juniper xing    102
# 69        w||a                                     blackR 5m v H3    172
# 70        w45a              juniper just above R on right side sb    -35
# 71        w46a                            Rs right side4m v pineR    404
# 72         w|a                                       sb 3m ^ slab    265
# 73         w|b                             Rs sb opp T top island    158
# 74        w||b               oak next to Rs 3m right sb at flat R    208
# 75        w||c                                        top s-curve    280
# 76         w^a                                        sb at stump    364
# 77       w50a                                    mid stacked wall     73
# 78        w51a                                  sb 5m ^ root xing    165
# 79        w59a                                     left root xing    160
# 80        w15b                                          mid chute    358
# 81      w57b7c                       Rs rt side just v cave trail     38
# 82        w55a                                  4m v wall v talus    317
# 83        w10a                               left side 2 Triple R    335
# 84         w2b                                 4m rt base 1 falls      0
# 85        w23a                              top wall opp lizard R    133
# 86        w40b                                             2falls    390
# 87        w56a                            left sb opp slab v slab    258
# 88        w15a                            juniper opp slab v slab    253
# 89      w53a.c                                  wall opp pyramidR    373
# 90        w21a                                           2tripleR    335
# 91         w.b             4m ^ sb opp bottom R wall v cave trail     34
# 92        w12b                                               slab    262
# 93        w43b                                    wall btwn H3/H4    185
# 94     w29b26c                                   top left 1 falls      0
# 95        w21b                                       Rs opp Oak R    418
# 96     w51b44c                     top Rwall on left v cave trail     30
# 97        w66b                      sb at mid wall v juniper xing    102
# 98        w64b                 bottom Rwall on right v cave trail     28
# 99        w42b                              Routcrop 10m v CC/CCC    230
# 100      w9b.t                 tree opp base Rwall v juniper xing     83
# 101       w33b                     Tree top of island v root xing    155
# 102        w1b                                left sb 5m v 1falls     -5
# 103      w3c.t                                left sb 5m v 1falls     -5
# 104    w35b28c                                            end ccc    240
# 105     w.b48c                                             Rs sb     -20
# 106     w.a18t                                          wall @ H4    194
# 107   w.a-c18t                                         wall at H4    194
# 108       w14b                           rt R wall 3m ^ 2 TripleR    338
# 109       w52b                     top Rwall on left v cave trail     30
# 110       w19b     [Rs opp oakR; loc not recorded in field notes]    NaN
# 111       w37b                                        R opp oak R    418
# 112       w48b                                       wall v talus    314
# 113       w63b                        left side 6m v Rs opp pineR    402
# 114       w60b                                               slab    262
# 115       w26b                   left opp mid wall v juniper xing    102
# 116       w46b                         oak 5m ^ bottom on rt side    -40
# 117        w4c                                       base 1 falls      0
# 118       w16b                                  left Rs 2m v pool    378
# 119      w7b.t                     Rs in sb 18m ^ 1 falls on logs     19
# 120      w8b.t                         base rt. wall v cave trail     30
# 121    w61b42t                                wall left 3m v pool    377
# 122       w24b                                          mid chute    358
# 123       w24b                                          mid chute    358
# 124       w27b                  mid wall below cave trail rt side     35
# 125       w11a            left side sb 3m ^ juniper xing @ cc/ccc    240
# 126       w17a                             Rs sb 1m v top of site    454
# 127       w29a                   sb 5m ^ bottom curved wall on rt     35
# 128       w11b                                   juniper @ cc/ccc    237
# 129       w44a                                     blackR 5m v H3    172
# 130       w52a                                  sb 5m ^ root xing    165
# 131       w18a                                    1m ^ opp Pine R    409
# 132       w31a                             T left sb 4m ^ lizardR    137
# 133       w31a  on small T (3cm dbh) 3m up from sb opp downed ...    223
# 134       w67b                         left side Rs 5m ^ lizard R    138
# 135       w55b                            left Rwall 10m ^ 1falls     10
# 136       w44b            right sb btwn 2tripleR and bottom chute    345
# 137        w6a                         3m ^ lizard R left side sb    136
# 138       w48a                                             2falls    390
# 139       w20a                                        Rs opp slab    262
# 140        w4a                            1m ^ cave trail rt side     46
# 141        w7a                                        flatR in sb    208
# 142       w47a                                            L in sb    -25
# 143       w49a                                   mid stacked wall     73
# 144       w30a                             T left sb 4m ^ lizardR    137
# 145       w41a                           left Rs 4m ^ top s curve    284
# 146       w40a                                    sb 3m v top CCC    240
# 147       w19a                            base juniper 5m ^ flatR    213
# 148       w33a                     rt side sb 4m v downed juniper    216
# 149       w38a             way up T opp downed juniper 4m ^ flatR    212
# 150        w|c     L sb at wall on left v right wall v cave trail     28
# 151       w36a                                     sb top s-curve    280
# 152        w+b                                              2oakR    445
# 153       w35a                               Rs left side oppH4.5    200
# 154       w39a                      sb bottom wall v juniper xing     85
# 155       w57a                     Rs right side 4m v slab v slab    254
# 156       w58a                     Rs right side 4m v slab v slab    254
# 157        w8a                             left side sb @ s-curve    280
# 158        w=a                                             CC/CCC    240
# 159      w53a                                              CC/CCC    240
# 160       w62a                                sb to left of chute    362
# 161       w54a                                             CC/CCC    240
# 162        NaN                            Rs sb at downed juniper    220
#
#       new.recap  painted                                               misc  \
# 0          Dead      NaN                                  Dead on ground !?
# 1         heard      NaN                                                NaN
# 2           NEW  painted                                              66-06
# 3           NEW  painted                                              65-06
# 4           NEW  painted                                              77-06
# 5           NEW  painted                                     pictures taken
# 6           NEW  painted                                          Tshed;Bss
# 7           NEW  painted                                                NaN
# 8           NEW  painted                                                NaN
# 9           NEW  painted                                                NaN
# 10          NEW  painted                                                NaN
# 11          NEW  painted                                                NaN
# 12          NEW  painted                                    T recently shed
# 13          NEW  painted                                                NaN
# 14          NEW  painted  gravid; multiple Pt on hindlegs in different s...
# 93        recap  painted  gravid; only three toes cut nothing missing on...
# 94        recap  painted  Tss, Bss; 2005 mark "w26c" still visible; not ...
# 95        recap  painted  gravid; old wound mid abdomen; partial break @ 21
# 96        recap  painted           gravid - w44c is old paint mark- GOT HER
# 97        recap  painted                                gave birth recently
# 98        recap  painted                                      recently shed
# 99        recap  painted                                                NaN
# 100       recap  painted                                            Bs; Tss
# 101       recap  painted  lost 80 mm of tail during capture and before m...
# 102       recap  painted                           wound mid dorsal rt side
# 103       recap  painted                               Bss; T recently shed
# 104       recap  painted  2005 mark "w28c" still visible, Tss on abdomin...
# 105       recap  painted                          old paint mark; added w.b
# 106       recap  painted      gravid; not shed since 2005 was w18t added .a
# 107       recap  painted  old mark w.a18t visible and changed to w.a-c18...
# 108       recap  painted                                                NaN
# 109       recap  painted                old paint mark (unreadable) on tail
# 110       recap  painted  [logically this guy must have been caught at R...
# 111       recap  painted                                             gravid
# 112       recap  painted                                                NaN
# 113       recap  painted                                                NaN
# 114       recap  painted                                                NaN
# 115       recap  painted  During capture 34 of tail lost; stored in vial...
# 116       recap  painted                                                NaN
# 117       recap  painted  gravid; not shed since last year; repainted ov...
# 118       recap  painted                                                NaN
# 119       recap  painted                            shed since last capture
# 120       recap  painted                                                NaN
# 121       recap  painted  last yr mark (w42t) still visible; repainted a...
# 122       recap  painted                gravid; Pt back and hind limbs; Bss
# 123       recap  painted  paaint mark too worn; NOT shed since last capt...
# 124       recap  painted                                             gravid
# 125       recap  painted                                                NaN
# 126       recap  painted                                                NaN
# 127       recap  painted                                                NaN
# 128       recap  painted                                                NaN
# 129       recap  painted                                                NaN
# 130       recap  painted                                                NaN
# 131       recap  painted                    loose scales B, B shed recently
# 132       recap  painted                                                NaN
# 133       recap      NaN  this animal has moved a lot since the earlier ...
# 134       recap  painted                                           salmon T
# 135       recap  painted                                                NaN
# 136       recap      NaN  caught just to check toes since she's way away...
# 137       recap  painted                                                NaN
# 138       recap  painted  faint last yr mark (w47b?) visible; blue throa...
# 139       recap  painted                                                NaN
# 140       recap  painted                                             gravid
# 141       recap  painted                                                NaN
# 142       recap  painted               very orange and blue throat (photos)
# 143       recap  painted                                                NaN
# 144       recap  painted                                                NaN
# 145       recap  painted  very faint orange throat spots; bit of a speck...
# 146       recap  painted                          faint orange throat spots
# 147       recap  painted  not shed since last year; w37a? Visible; two b...
# 148       recap  painted                                                NaN
# 149       recap  painted  w33a paint mark from 05 still visible!; repain...
# 150       recap  painted                                                NaN
# 151       recap  painted                                                NaN
# 152       recap  painted  question whether 6-18 or 6-19 toes; 6-19 match...
# 153       recap  painted                                                NaN
# 154       recap  painted                             blue throat; no orange
# 155       recap  painted                 photos of bite marks on left flank
# 156       recap  painted                           big orange throat; photo
# 157      reecap  painted                                             gravid
# 158    sighting      NaN                                                NaN
# 159    sighting      NaN                                                NaN
# 160    sighting      NaN                                                NaN
# 161    sighting      NaN                     note kink on tail 4mm from end
# 162    sighting      NaN  not caught; read toes because mark barely visible
#
#                                                   vial
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                28-06
# 6                                                01-06
# 7                                                02-06
# 8                                                03-06
# 9                                                04-06
# 10                                               07-06
# 11                                               08-06
# 12                                               09-06
# 13                                               10-06
# 14                                               11-06
# 15                                               12-06
# 16                                               14-06
# 17                                               15-06
# 18                                               16-06
# 19                                               20-06
# 20                                               22-06
# 21                                               24-06
# 22                                               25-06
# 23                                               26-06
# 24                                               29-06
# 25                                               31-06
# 26                                               34-06
# 27                                               39-06
# 28                                               51-06
# 29                                               52-06
# 30                                               54-06
# 31                               loaded with Pt on HLs
# 32                                              gravid
# 33                         shedding nuchals; Trec shed
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                               83-06
# 38                                                 NaN
# 39                                               40-06
# 40                                               23-06
# 41                                               27-06
# 42                                               32-06
# 43                                               36-06
# 44                                               37-06
# 45                                               38-06
# 46                                               41-06
# 47                                               05-06
# 48                                               06-06
# 49                                               13-06
# 50                                               18-06
# 51                                               48-06
# 52                                               56-06
# 53                                               19-06
# 54                                               21-06
# 55                                               30-06
# 56                                               35-06
# 57                                               49-06
# 58                                               50-06
# 59                                               53-06
# 60                                               55-06
# 61                                                 NaN
# 62                                                 NaN
# 63   did "full show" (sidle hop in Sv terms) to w34...
# 64                                                 NaN
# 65    blue throat; B&T rec shed; loose scales dorsal T
# 66                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69                                                 NaN
# 70                                               78-06
# 71                                               80-06
# 72                                         photo taken
# 73                                                 NaN
# 74                                                 NaN
# 75                                                 NaN
# 76                                               82-06
# 77                                               81-06
# 78                                               82-06
# 79                                               84-06
# 80                                                 NaN
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 87                                                 NaN
# 88                                                 NaN
# 89         hasn't shed since last yr; old w53a visible
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                              33-06
# 102                                                NaN
# 103                                                NaN
# 104                                                NaN
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109                                                NaN
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                              17-06
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
# 151  yellow sopt on left side just anterior to left...
# 152                                                NaN
# 153                                                NaN
# 154                                                NaN
# 155                                                NaN
# 156                                                NaN
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN

# %% [markdown]
# We'll create a df, *df*, with no data, but columns from our desired columns, *i.e.* the keys for coldict, as a placeholder to which we can append new data.

# %%
df = pd.DataFrame(columns=coldict.keys())
df
# Out:
# Empty DataFrame
# Columns: [species, date, sex, svl, tl, rtl, mass, paint.mark, location, meters, new.recap, painted, misc, vial, autotomized, sighting, toes, filename]
# Index: []

# %% [markdown]
# Now we will read in all of the successfully split files, clean the column names, and concatenate them into one large df.

# %%
for file in splitfiles:
    df = pd.concat([df,mapndrop(pd.read_excel(file,dtype=str),uniquecols2dict)],sort=True)
    print(df.shape[0])
print("\n\nFinal df has {} columns and {} rows.".format(df.shape[1],df.shape[0]))
df.head()
# Out:
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 241
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 423
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 520
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 999
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 1162
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 2639
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 3656
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 3762
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 3924
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 4009
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 4108
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 4789
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 5587
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 5796
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 5860
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 5963
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 6165
# Successfully mapped columns for df.
# Successfully dropped unnecessary columns for df.
# 6299
#
#
# Final df has 18 columns and 6299 rows.
#   autotomized                 date filename           location  mass meters  \
# 0         NaN  2015-07-06 00:00:00      NaN  L 5m^ bottom site   9.7    -35
# 1         NaN  2015-07-06 00:00:00      NaN              SB 5m  14.3    -25
# 2         NaN  2015-07-06 00:00:00      NaN      SB 8m v bowl   14.8    -16
# 3         NaN  2015-07-06 00:00:00      NaN     L SB^ 1 falls   11.3      1
# 4         NaN  2015-07-06 00:00:00      NaN       SB 20^1falls    10     20
#
#                     misc new.recap paint.mark painted rtl sex sighting  \
# 0   B recently shed; TSS       new        w2a     yes   0   f      NaN
# 1                    NaN       new       w21a     yes  33   m      NaN
# 2                    NaN       new        w3a     yes  55   m      NaN
# 3                    NaN       new        w6a     yes  15   f      NaN
# 4  shedding; poop 15-101       new      w7a.c     yes   0   f      NaN
#
#   species svl  tl        toes   vial
# 0       j  67  97      5-7-13  15-02
# 1       j  73  71   5-7-14-20  15-16
# 2       j  78  75   5-7-13-16  15-03
# 3       j  75  50        5-11    NaN
# 4       j  66  84   5-7-13-17  15-04

# %%
df = df.reindex(['species', 'toes', 'sex', 'date', 'svl', 'tl', 'rtl', 'autotomized', 'mass', 
                 'location', 'meters', 'new.recap', 'painted', 'sighting', 
                 'paint.mark', 'vial', 'misc'], axis=1)
df.head()
# Out:
#   species        toes sex                 date svl  tl rtl autotomized  mass  \
# 0       j      5-7-13   f  2015-07-06 00:00:00  67  97   0         NaN   9.7
# 1       j   5-7-14-20   m  2015-07-06 00:00:00  73  71  33         NaN  14.3
# 2       j   5-7-13-16   m  2015-07-06 00:00:00  78  75  55         NaN  14.8
# 3       j        5-11   f  2015-07-06 00:00:00  75  50  15         NaN  11.3
# 4       j   5-7-13-17   f  2015-07-06 00:00:00  66  84   0         NaN    10
#
#             location meters new.recap painted sighting paint.mark   vial  \
# 0  L 5m^ bottom site    -35       new     yes      NaN        w2a  15-02
# 1              SB 5m    -25       new     yes      NaN       w21a  15-16
# 2      SB 8m v bowl     -16       new     yes      NaN        w3a  15-03
# 3     L SB^ 1 falls       1       new     yes      NaN        w6a    NaN
# 4       SB 20^1falls     20       new     yes      NaN      w7a.c  15-04
#
#                     misc
# 0   B recently shed; TSS
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4  shedding; poop 15-101

# %%
df.shape
# Out:
# (6299, 17)

# %% [markdown]
# # Exporting Data
# [Top](#TOC)

# %% [markdown]
# Here we call the function, *namefile*, to create a timestamped name for file to be exported.  You can find the code for *namefile* in [Functions](#functions).

# %%
filename = namefile('Appended and Trimmed CC Data 2000-2017')
os.chdir(outputGandolf)
df.to_csv(filename,index = False)
print("\'{}\' has been saved to \'{}\' and the corresponding drive google drive location."\
      .format(filename, outputGandolf))
# Out:
# 'Appended and Trimmed CC Data 2000-2017_2020-02-15 18hrs53min.csv' has been saved to 'C:/Users/craga/Google Drive/TailDemography/Cleaned Combined Data' and the corresponding drive google drive location.

# %% [markdown]
# # Where to Next
# [Back to Top](#Table-of-Contents)
#
# Next proceed to Cleaning CC (Part 2).
