# %% [markdown]
# # Cleaning CC data

# %% [markdown]
# This python notebook operates on a csv created after editing in open refine and is designed to finish cleaning columns of interest which were easier to clean in python.

# %% [markdown]
# ## Setting up Python
#
# Here we import necessary packages.
# This chunk may take a while.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Use this chunk to import from google sheets

# %% [markdown]
# import gspread
# from oauth2client.service_account import ServiceAccountCredentials
# ####use creds to create a client to interact with the Google Drive API
# scope = ['https://spreadsheets.google.com/feeds']
# creds = ServiceAccountCredentials.from_json_keyfile_name('TD_client.json', scope)
# client = gspread.authorize(creds)
#
# data = client.open("mapped-data-all_18-01-08_post_openrefine.csv").sheet1
# df=pd.DataFrame(data.get_all_records())

# %% [markdown]
# ### Use this chunk to read data from local folder on Chris' machine

# %%
df=pd.read_csv('C:/Users/Christopher/Google Drive/TailDemography/outputFiles/mapped-data-all_18-01-08_post_openrefine.csv')

# %% [markdown]
# Let's take a look at the data

# %%
print("\nThere are {} data points in our data set.".format(df.shape[0]))
# Out:
# There are 8197 data points in our data set.

# %%
print("\nThe columns in the data have the following data types:\n{}".format(df.dtypes))
# Out:
# The columns in the data have the following data types:
# species                object
# toes                   object
# date                   object
# sex                    object
# svl                   float64
# tl                    float64
# rtl_orig               object
# mass                   object
# paint.mark             object
# location               object
# meters                 object
# new.recap              object
# painted                object
# misc                   object
# vial                   object
# year                    int64
# rtl                   float64
# autotomized              bool
# new.recap_orig         object
# sighting               object
# review_sex               bool
# review_species           bool
# review_painted           bool
# review_new.recap         bool
# review_rtl               bool
# forceMale                bool
# forceFemale              bool
# forceRecap               bool
# forceNew                 bool
# forceSighting            bool
# drop_species             bool
# drop_morphometrics       bool
# dtype: object

# %% [markdown]
# ## Correcting class of columns

# %%
#We need to add real error handling into these conversion chunks

##Convert integer columns to int
intCols = ['meters','year']
df[intCols]=df[intCols].astype(int,errors='ignore')

##Convert numeric columns to numeric
numCols = ['svl','tl','rtl','rtl_orig','mass']
df[numCols]=df[numCols].apply(pd.to_numeric,errors='coerce')

##Convert string columns to str
strCols = ['toes','sex','species','vial']
df[strCols]=df[strCols].astype(str, errors='ignore')

#Convert date to datetime
df.loc[df.date=="NA"]=np.nan
df.date = pd.to_datetime(df.date,errors='coerce')

##Convert bool columns to bool
boolCols = ['review_sex','review_species','review_painted','review_new.recap',\
            'review_rtl','forceMale','forceFemale','forceRecap','forceNew',\
            'forceSighting','drop_species','drop_morphometrics','autotomized']
df[boolCols]=df[boolCols].astype(bool, errors='ignore')

# %%
print("\nAfter applying the above changes, the data types re as follows:\n{}".format(df.dtypes))
# Out:
# After applying the above changes, the data types re as follows:
# species                       object
# toes                          object
# date                  datetime64[ns]
# sex                           object
# svl                          float64
# tl                           float64
# rtl_orig                     float64
# mass                         float64
# paint.mark                    object
# location                      object
# meters                        object
# new.recap                     object
# painted                       object
# misc                          object
# vial                          object
# year                         float64
# rtl                          float64
# autotomized                     bool
# new.recap_orig                object
# sighting                      object
# review_sex                      bool
# review_species                  bool
# review_painted                  bool
# review_new.recap                bool
# review_rtl                      bool
# forceMale                       bool
# forceFemale                     bool
# forceRecap                      bool
# forceNew                        bool
# forceSighting                   bool
# drop_species                    bool
# drop_morphometrics              bool
# dtype: object

# %% [markdown]
# ## Remove leading and trailing whitespaces

# %% [markdown]
# for col in df:
#     print(len(col))# returns unique lengths of sex
#     col=col.strip()

# %% [markdown]
# for col in df:
#     col=col.strip()

# %% [markdown]
# ## Cleaning toes column

# %%
#df.toes.astype(str)
#df.toes=df.toes.str.strip()#remove white spaces before and after the toes
pattern1=".( - )." #toes entries with space around hyphen
pattern2=".( \d+ )." #toes entries with space around numbers
pattern3=".(')."
print("\nThere are {} entries in the data set.\
        \nOf these, there are {} toe marks with spaces surrounding hyphens,\
        \n{} with spaces surrounding numbers,\
        \nand {} with an apostrophe preceeding the entry."\
      .format(df.shape[0]\
              ,df.loc[df.toes.str.match(pattern1)==True].shape[0]\
              ,df.loc[df.toes.str.match(pattern2)==True].shape[0],\
              df.loc[df.toes.str.match(pattern3)==True].shape[0]))
# Out:
# There are 8197 entries in the data set.
# Of these, there are 38 toe marks with spaces surrounding hyphens,
# 213 with spaces surrounding numbers,
# and 0 with an apostrophe preceeding the entry.

# %%
df.loc[df.toes=='nan','toes'] = np.nan

# %%
df.loc[df.toes.str.match(pattern1)==True]
# Out:
#      species                               toes       date sex   svl     tl  \
# 6055       j                         4 - 6 - 12 2011-06-20   m  68.0  101.0
# 6056       j                         4 - 6 - 13 2011-06-28   m  77.0  106.0
# 6057      uo                             6 - 15 2011-06-20   m  49.0   83.0
# 6058      uo                             6 - 16 2011-06-28   f  49.0   72.0
# 6059      uo                             6 - 17 2011-07-02   f  48.0   69.0
# 6060       v                    3 - 9 - 13 - 20 2011-06-22   m  46.0   60.0
# 6061       v                    3 - 9 - 14 - 16 2011-06-27   m  49.0   64.0
# 6062       v                    3 - 9 - 14 - 17 2011-06-30   m  49.0   46.0
# 6063       v                    3 - 9 - 14 - 18 2011-07-03   f  49.0   62.0
# 6064       j                    4 - 6 - 11 - 20 2011-06-20   f  61.0   81.0
# 6065       j                    4 - 6 - 12 - 16 2011-06-20   m  77.0  101.0
# 6066       j                    4 - 6 - 12 - 18 2011-06-22   m  69.0   87.0
# 6067       j                    4 - 6 - 12 - 19 2011-06-22   f  60.0   82.0
# 6068       j                    4 - 6 - 13 - 16 2011-06-30   m  73.0  103.0
# 6069       j                    4 - 6 - 13 - 17 2011-07-01   f  70.0   73.0
# 6070       j                    4 - 6 - 13 - 19 2011-06-30   f  76.0   68.0
# 6082       v                    3 - 9 - 13 - 16 2011-06-20   m  50.0   66.0
# 6083       j                         1 - 8 - 11 2011-06-19   f  77.0  108.0
# 6084       j                         2 - 8 - 13 2011-06-21   f  70.0   73.0
# 6085       j                         3 - 7 - 15 2011-07-02   f  59.0   78.0
# 6086       j                         3 - 9 - 15 2011-06-23   f  75.0   82.0
# 6087       j                             1 - 12 2011-06-19   f  74.0   76.0
# 6088      uo                             8 - 16 2011-06-25   f  48.0   61.0
# 6089       j                        1 - 12 - 17 2011-06-27   f  80.0  106.0
# 6090       j                       1 - 15  - 17 2011-06-19   m  82.0   99.0
# 6091       v                    1 - 7 - 12 - 18 2011-06-30   f  60.0   74.0
# 6092       j                    1 - 7 - 13 - 18 2011-06-19   f  78.0  106.0
# 6093       j                    1 - 7 - 14 - 19 2011-06-19   m  80.0   73.0
# 6094       j                    2 - 6 - 12 - 20 2011-06-30   f  76.0  100.0
# 6095       j                    2 - 9 - 15 - 20 2011-06-19   f  75.0   41.0
# 6096       v                    3 - 7 - 13 - 18 2011-06-30   m  52.0   72.0
# 6097       j                    3 - 7 - 15 - 16 2011-06-21   f  58.0   72.0
# 6098       v  3 - 8 - 11 - 12 - 13 - 14 15 - 16 2011-06-30   f  60.0   75.0
# 6099       v                    3 - 8 - 11 - 19 2011-06-30   m  56.0   73.0
# 6100       j                    4 - 6 - 11 - 19 2011-06-20   f  55.0   75.0
# 6101       j                b - 2 - 7 - 13 - 20 2011-06-28   m  85.0  119.0
# 6102       j                    b - 4 - 11 - 20 2011-06-28   f  62.0   84.0
# 6103       v                    b - 7 - 11 - 16 2011-06-26   f  60.0   50.0
#
#       rtl_orig  mass paint.mark                              location  \
# 6055       0.0   9.2       g20b                            15m up CCC
# 6056       0.0  13.8       g40b   big juniper right 8m ^ juniper Xing
# 6057       0.0   4.0        g.t                             opp oak R
# 6058       0.0   4.2        g.b                                CC/CCC
# 6059       0.0   4.0        g.c                                   H4b
# 6060       0.0   3.7        g6c                    left Rs opp Pine R
# 6061       0.0   4.0        g8c                    left Rs 3m ^ oak R
# 6062      12.0   4.3        g9c                2m ^ cave trail opp sb
# 6063       0.0   4.0       g14c                          2m v pool sb
# 6064       0.0   6.6       g17b        4m ^ left side SB Juniper Xing
# 6065       0.0  11.7       g24b                            mid- chute
# 6066      15.0  10.3       g29b           R bottom bowl v 1 falls -8m
# 6067       0.0   6.6       g30b                       1m v cave trail
# 6068       0.0  15.0        gEb                          2m ^ 1 falls
# 6069      45.0  10.2       g42b          top curved wall v cave trail
# 6070      28.0   9.4        gAb                   Rs just below site
# 6082       0.0   4.8        g1c                        5m ^ root Xing
# 6083       0.0  16.0        g7b                                CC/CCC
# 6084      54.0  10.4       g26b                    stream bed 2m v H5
# 6085       0.0   6.0       g43b                       sb juniper xing
# 6086      56.0   7.7       g35b                  right Rs bottom bowl
# 6087      31.0  10.7        g5b                                CC/CCC
# 6088       4.0   3.3        g.a                   tree @ juniper xing
# 6089       0.0  11.5       g37b               left wall ^ cave trail
# 6090      33.0  15.5        g4b                                CC/CCC
# 6091       0.0   9.8        gLc                                  tree
# 6092       0.0  16.0        g8b                                  pool
# 6093      52.0  20.0     g10b.t                             opp oak R
# 6094       0.0  10.4       g41b                   R wall v cave trail
# 6095      15.0  10.5        g3b                                    H4
# 6096       0.0   5.3       g10c                 R rt sb 3m ^ lizard R
# 6097       0.0   8.8        g2c  Rs left stream bed opp lizard R ^ 3m
# 6098       0.0   9.0       g13c                R left sb @ 1 triple R
# 6099       0.0   6.6       g12c                      R wall rt up CCC
# 6100       0.0   4.0       g13b            below one falls tree 1m up
# 6101       0.0  18.5       g38b                           bottom bowl
# 6102       0.0   5.3       g39b              R wall 4m ^ juniper xing
# 6103      30.0   8.8        g7c                                    sb
#
#             ...         review_painted review_new.recap review_rtl forceMale  \
# 6055        ...                  False            False      False     False
# 6056        ...                  False            False      False     False
# 6057        ...                  False            False      False     False
# 6058        ...                  False            False      False     False
# 6059        ...                  False            False      False     False
# 6060        ...                  False            False      False     False
# 6061        ...                  False            False      False     False
# 6062        ...                  False            False      False     False
# 6063        ...                  False            False      False     False
# 6064        ...                  False            False      False     False
# 6065        ...                  False            False      False     False
# 6066        ...                  False            False      False     False
# 6067        ...                  False            False      False     False
# 6068        ...                  False            False      False     False
# 6069        ...                  False            False      False     False
# 6070        ...                  False            False      False     False
# 6082        ...                  False             True      False     False
# 6083        ...                  False            False      False     False
# 6084        ...                  False            False      False     False
# 6085        ...                  False            False      False     False
# 6086        ...                  False            False      False     False
# 6087        ...                  False            False      False     False
# 6088        ...                  False            False      False     False
# 6089        ...                  False            False      False     False
# 6090        ...                  False            False      False     False
# 6091        ...                  False            False      False     False
# 6092        ...                  False            False      False     False
# 6093        ...                  False            False      False     False
# 6094        ...                  False            False      False     False
# 6095        ...                  False            False      False     False
# 6096        ...                  False            False      False     False
# 6097        ...                  False            False      False     False
# 6098        ...                  False            False      False     False
# 6099        ...                  False            False      False     False
# 6100        ...                  False            False      False     False
# 6101        ...                  False            False      False     False
# 6102        ...                  False            False      False     False
# 6103        ...                  False            False      False     False
#
#      forceFemale  forceRecap  forceNew  forceSighting drop_species  \
# 6055       False       False     False          False        False
# 6056       False       False     False          False        False
# 6057       False       False     False          False         True
# 6058       False       False     False          False         True
# 6059       False       False     False          False         True
# 6060       False       False     False          False        False
# 6061       False       False     False          False        False
# 6062       False       False     False          False        False
# 6063       False       False     False          False        False
# 6064       False       False     False          False        False
# 6065       False       False     False          False        False
# 6066       False       False     False          False        False
# 6067       False       False     False          False        False
# 6068       False       False     False          False        False
# 6069       False       False     False          False        False
# 6070       False       False     False          False        False
# 6082       False       False      True          False        False
# 6083       False       False     False          False        False
# 6084       False       False     False          False        False
# 6085       False       False     False          False        False
# 6086       False       False     False          False        False
# 6087       False       False     False          False        False
# 6088       False       False     False          False         True
# 6089       False       False     False          False        False
# 6090       False       False     False          False        False
# 6091       False       False     False          False        False
# 6092       False       False     False          False        False
# 6093       False       False     False          False        False
# 6094       False       False     False          False        False
# 6095       False       False     False          False        False
# 6096       False       False     False          False        False
# 6097       False       False     False          False        False
# 6098       False       False     False          False        False
# 6099       False       False     False          False        False
# 6100       False       False     False          False        False
# 6101       False       False     False          False        False
# 6102       False       False     False          False        False
# 6103       False       False     False          False        False
#
#      drop_morphometrics
# 6055              False
# 6056              False
# 6057              False
# 6058              False
# 6059              False
# 6060              False
# 6061              False
# 6062              False
# 6063              False
# 6064              False
# 6065              False
# 6066              False
# 6067              False
# 6068              False
# 6069              False
# 6070              False
# 6082              False
# 6083              False
# 6084              False
# 6085              False
# 6086              False
# 6087              False
# 6088              False
# 6089              False
# 6090              False
# 6091              False
# 6092              False
# 6093              False
# 6094              False
# 6095              False
# 6096              False
# 6097              False
# 6098              False
# 6099              False
# 6100              False
# 6101              False
# 6102              False
# 6103              False
#
# [38 rows x 32 columns]

# %%
df.loc[df.toes.str.match(pattern2)==True]
# Out:
#      species               toes       date  sex   svl     tl  rtl_orig  mass  \
# 3387       v            3 13 16 2004-07-02    m  54.0   51.0      38.0   5.2
# 3389       v             4 6 11 2004-07-02    m  49.0   66.0       0.0   4.5
# 3390       v             4 6 12 2004-07-02    m  45.0   62.0       0.0   3.3
# 3395       v             4 6 13 2004-07-02    f  57.0   68.0       0.0   7.6
# 3413       v             4 6 14 2004-07-03    f  50.0   69.0       0.0   4.1
# 3417       v             4 6 15 2004-07-03    f  49.0   70.0       0.0   7.0
# 3421       v             4 6 16 2004-07-03    m  44.0   64.0       0.0   3.6
# 3422       v             4 6 17 2004-07-03    f  39.0   59.0       0.0   3.2
# 3424       v             4 6 18 2004-07-03    f  52.0   68.0       0.0   4.6
# 3425       v             1 9 16 2004-07-03    m  55.0   73.0       0.0   5.3
# 3433       v             4 6 19 2004-07-03    f  48.0   59.0       0.0   3.4
# 3434       v             4 6 20 2004-07-03    m  48.0   46.0      -1.0   3.5
# 3440       v             1 8 12 2004-07-03    m  58.0   76.0       0.0   5.2
# 3444       v            2 11 16 2004-07-03    m  53.0   62.0      16.0   5.5
# 3445       v             4 6 11 2004-07-03  nan   NaN    NaN       NaN   NaN
# 3447       j            2 12 17 2004-07-03    m  91.0   67.0       2.0  23.8
# 3456       j             1 6 14 2004-07-04    m  85.0  126.0       0.0  25.0
# 3459       v             4 7 11 2004-07-04    m  38.0   59.0       0.0   3.0
# 3462       v             4 7 12 2004-07-04    f  49.0   57.0       0.0   3.8
# 3466       v             4 7 13 2004-07-04    f  52.0   70.0       0.0   5.1
# 3468       v             4 7 14 2004-07-04    f  63.0   69.0       0.0   9.6
# 3475       v             4 7 15 2004-07-04    f  53.0   67.0       0.0   4.8
# 3498       v             1 8 15 2004-07-05    m  52.0   78.0       0.0   4.6
# 3534       v             4 7 19 2004-07-06    m  42.0   42.0      -1.0   2.5
# 3630       v             4 8 15 2004-07-10    f  45.0   50.0      30.0   4.3
# 3631       v             4 8 16 2004-07-10    m  45.0   60.0       0.0   3.4
# 3741       v             4 6 11 2004-07-21    f  53.0   66.0       0.0   4.9
# 4071       j          4 6 14 16 2006-05-20    m  62.0   78.0       0.0   7.8
# 4072       j          4 6 14 18 2006-05-20    f  58.0   74.0       0.0   7.6
# 4073       j          4 6 14 19 2006-05-20    f  52.0   76.0       0.0   4.3
# ...      ...                ...        ...  ...   ...    ...       ...   ...
# 6115       j  b 3 - 6 - 11 - 17 2011-06-20    m  70.0  100.0       0.0  11.4
# 6116       j  b 3 - 6 - 11 - 20 2011-06-20    m  72.0  100.0       0.0  13.6
# 6117       j      b 6 - 14 - 20 2011-06-20    f  73.0   65.0      43.0  10.0
# 6305       j            5 11 16 2014-07-05    f  74.0   67.0      30.0  14.5
# 6307       v             4 6 15 2014-07-06    m  42.0   56.0       0.0   2.5
# 6308       j          4 6 12 20 2014-07-05    m  91.0  126.0       0.0  24.5
# 6311       v             4 6 14 2014-07-05    m  50.0   71.0       0.0   4.0
# 6312       v             4 7 20 2014-07-13    f  54.0   67.0       0.0   3.9
# 6313       j             5 6 17 2014-07-06    f  66.0   94.0       0.0   7.7
# 6315       v             3 6 19 2014-07-05    m  50.0   15.0       3.0   3.8
# 6316       v             4 6 12 2014-07-05    m  47.0   67.0       0.0   3.5
# 6318       v             4 6 13 2014-07-05    m  47.0   68.0       0.0   3.5
# 6319       v             4 6 16 2014-07-06    m  47.0   64.0       0.0   3.4
# 6324       v             3 6 12 2014-07-05    m  53.0   68.0       0.0   4.8
# 6325       j             5 6 16 2014-07-05    f  69.0   93.0       0.0  10.7
# 6333       v             4 7 15 2014-07-08    f  55.0   70.0       0.0   4.7
# 6341       v             3 6 20 2014-07-05    m  51.0   71.0       0.0   4.3
# 6343       j             5 7 13 2014-07-10    m  76.0  102.0       0.0  16.0
# 6352       v            7 14 18 2014-07-11    f  63.0   58.0      36.0   7.1
# 6354       v             4 6 18 2014-07-06    f  57.0   69.0       0.0   6.3
# 6356       v             4 6 11 2014-07-05    m  51.0   61.0       0.0   4.2
# 6360       j             5 6 18 2014-07-06    m  75.0  107.0       0.0  14.5
# 6364       v             4 7 17 2014-07-10    m  51.0   79.0       0.0   4.6
# 6368       j             5 7 14 2014-07-13    m  83.0  119.0       0.0  19.0
# 6377       v             4 6 19 2014-07-06    m  48.0   65.0       0.0   4.1
# 6381       j            5 13 17 2014-07-05    f  75.0  100.0       0.0  14.3
# 6388       j            8 13 19 2014-07-11    m  88.0  116.0       0.0  25.2
# 6399       v             4 7 19 2014-07-13    m  50.0   60.0       0.0   5.4
# 6400       v             4 7 18 2014-07-11    f  58.0   69.0       0.0   4.9
# 6401       v          3 9 14 16 2014-07-11    m  57.0   73.0       0.0   6.6
#
#      paint.mark                             location        ...          \
# 3387        wTb                       sb 10m v falls        ...
# 3389        wAc                              see wAa        ...
# 3390        wAb           3 m above cave trail on rt        ...
# 3395        w1a               on pine at top of site        ...
# 3413        w2a                       8m^ cave trail        ...
# 3417        w2b             sb 1m v top of rock wall        ...
# 3421        w2c                           sb 1m v H3        ...
# 3422        w3a                             sb at H3        ...
# 3424        w3b          1m v flat rock on left side        ...
# 3425        w3c         1m v opposite fallen juniper        ...
# 3433        w4a                       sb 1m^ 2 falls        ...
# 3434        w4b                          1m^ 2 falls        ...
# 3440        w4c          log in sb 3m^ 1 triple rock        ...
# 3444        w5b          tree left side opp fox hole        ...
# 3445        wAc                    at the cave trail        ...
# 3447        wMb      bottom r wall bellow cave trail        ...
# 3456        wOa        rock on rt side at cave trail        ...
# 3459        w5c             rt side 2m^ stacked wall        ...
# 3462        w6a                                   H3        ...
# 3466        w6c              tree opp downed Juniper        ...
# 3468         w8                                 slab        ...
# 3475         w9                  rocks opp pine rock        ...
# 3498        w13          rt side 2m^ 1st triple rock        ...
# 3534        w18           2m v lizard rock left side        ...
# 3630        w28                   5m^ chihuahua pine        ...
# 3631        w29                   5m^ chihuahua pine        ...
# 3741      w144b                      sb @ cave trail        ...
# 4071        w1t                  left sb 5m v 1falls        ...
# 4072        w2b                  left sb 5m v 1falls        ...
# 4073        w5b               4m v 1 falls left side        ...
# ...         ...                                  ...        ...
# 6115       g25b                         top island T        ...
# 6116       g16b           bottom wall v juniper Xing        ...
# 6117       g15b                         1m ^ 1 falls        ...
# 6305       o29c                        in the sb -55        ...
# 6307       o28a                             L sb -50        ...
# 6308       o30c                            log @ -45        ...
# 6311       o27a                                   -5        ...
# 6312       o45a                         2m v 1 falls        ...
# 6313       o33c                     rt side 1 falls         ...
# 6315       o18a                      left wall @ 15         ...
# 6316       o25a                              sb @ 15        ...
# 6318       o26a                              sb @ 20        ...
# 6319       o29a              left SB 20 m ^ 1 falls         ...
# 6324       o20a       bottom left wall ^ cave trail         ...
# 6325       o31c             3 m ^ cave trail canyon         ...
# 6333       o38a      L sb opp wvwv juniper crossing         ...
# 6341       o22a                       bottom island         ...
# 6343       o39a                       sb mid island         ...
# 6352       o35a           left sb opp downed juniper        ...
# 6354       o30a             rt sb 5 m below L cc/ccc        ...
# 6356       o24a  mid wall below juniper crossing opp        ...
# 6360       o34c                           L @ cc/ccc        ...
# 6364       o40a                        sb @ juniper         ...
# 6368       o40c                                 slab        ...
# 6377       o31a                            triple R         ...
# 6381       o32c             top rt wall ^ 2 triple R        ...
# 6388       o39c                            wall pool        ...
# 6399       o44a                          5m ^ oak R         ...
# 6400       o42a                             top site        ...
# 6401       o41a                      rt sb 1m ^ site        ...
#
#      review_painted review_new.recap review_rtl forceMale forceFemale  \
# 3387          False            False      False     False       False
# 3389          False            False      False     False       False
# 3390          False            False      False     False       False
# 3395          False            False      False     False       False
# 3413          False            False      False     False       False
# 3417          False            False      False     False       False
# 3421          False            False      False     False       False
# 3422          False            False      False     False       False
# 3424          False            False      False     False       False
# 3425          False            False      False     False       False
# 3433          False            False      False     False       False
# 3434          False            False      False     False       False
# 3440          False            False      False     False       False
# 3444          False            False      False     False       False
# 3445          False             True      False     False       False
# 3447          False            False      False     False       False
# 3456          False            False      False     False       False
# 3459          False            False      False     False       False
# 3462          False            False      False     False       False
# 3466          False            False      False     False       False
# 3468          False            False      False     False       False
# 3475          False            False      False     False       False
# 3498          False            False      False     False       False
# 3534          False            False      False     False       False
# 3630          False            False      False     False       False
# 3631          False            False      False     False       False
# 3741          False            False      False     False       False
# 4071          False            False      False     False       False
# 4072          False            False      False     False       False
# 4073          False            False      False     False       False
# ...             ...              ...        ...       ...         ...
# 6115          False            False      False     False       False
# 6116          False            False      False     False       False
# 6117          False            False      False     False       False
# 6305          False            False      False     False       False
# 6307          False            False      False     False       False
# 6308          False            False      False     False       False
# 6311          False            False      False      True       False
# 6312          False            False      False     False       False
# 6313          False            False      False     False       False
# 6315          False            False      False     False       False
# 6316          False            False      False     False       False
# 6318          False            False      False     False       False
# 6319          False            False      False     False       False
# 6324          False            False      False     False       False
# 6325          False            False      False     False       False
# 6333          False            False      False     False       False
# 6341          False            False      False     False       False
# 6343          False            False      False     False       False
# 6352          False            False      False     False       False
# 6354          False            False      False     False       False
# 6356          False            False      False     False       False
# 6360          False            False      False     False       False
# 6364          False            False      False     False       False
# 6368          False            False      False     False       False
# 6377          False             True      False     False       False
# 6381          False            False      False     False       False
# 6388          False            False      False     False       False
# 6399          False            False      False     False       False
# 6400          False            False      False     False       False
# 6401          False            False      False     False       False
#
#       forceRecap  forceNew  forceSighting drop_species drop_morphometrics
# 3387       False     False          False        False              False
# 3389       False     False          False        False              False
# 3390       False     False          False        False              False
# 3395       False     False          False        False              False
# 3413       False     False          False        False              False
# 3417       False     False          False        False              False
# 3421       False     False          False        False              False
# 3422       False     False          False        False              False
# 3424       False     False          False        False              False
# 3425       False     False          False        False              False
# 3433       False     False          False        False              False
# 3434       False     False          False        False              False
# 3440       False     False          False        False              False
# 3444       False     False          False        False              False
# 3445       False     False          False        False               True
# 3447       False     False          False        False              False
# 3456       False     False          False        False              False
# 3459       False     False          False        False              False
# 3462       False     False          False        False              False
# 3466       False     False          False        False              False
# 3468       False     False          False        False              False
# 3475       False     False          False        False              False
# 3498       False     False          False        False              False
# 3534       False     False          False        False              False
# 3630       False     False          False        False              False
# 3631       False     False          False        False              False
# 3741       False     False          False        False              False
# 4071       False     False          False        False              False
# 4072       False     False          False        False              False
# 4073       False     False          False        False              False
# ...          ...       ...            ...          ...                ...
# 6115       False     False          False        False              False
# 6116       False     False          False        False              False
# 6117       False     False          False        False              False
# 6305       False     False          False        False              False
# 6307       False     False          False        False              False
# 6308       False     False          False        False              False
# 6311       False     False          False        False              False
# 6312       False     False          False        False              False
# 6313       False     False          False        False              False
# 6315       False     False          False        False              False
# 6316       False     False          False        False              False
# 6318       False     False          False        False              False
# 6319       False     False          False        False              False
# 6324       False     False          False        False              False
# 6325       False     False          False        False              False
# 6333       False     False          False        False              False
# 6341       False     False          False        False              False
# 6343       False     False          False        False              False
# 6352       False     False          False        False              False
# 6354       False     False          False        False              False
# 6356       False     False          False        False              False
# 6360       False     False          False        False              False
# 6364       False     False          False        False              False
# 6368       False     False          False        False              False
# 6377       False     False          False        False              False
# 6381       False     False          False        False              False
# 6388       False     False          False        False              False
# 6399       False     False          False        False              False
# 6400       False     False          False        False              False
# 6401       False     False          False        False              False
#
# [213 rows x 32 columns]

# %%
df.loc[df.toes.str.match(pattern3)==True]
# Out:
# Empty DataFrame
# Columns: [species, toes, date, sex, svl, tl, rtl_orig, mass, paint.mark, location, meters, new.recap, painted, misc, vial, year, rtl, autotomized, new.recap_orig, sighting, review_sex, review_species, review_painted, review_new.recap, review_rtl, forceMale, forceFemale, forceRecap, forceNew, forceSighting, drop_species, drop_morphometrics]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# ### Correcting these patterns

# %%
df.loc[df.toes.str.match(pattern1)==True]=df.loc[df.toes.str.match(pattern1)==True].replace(" ","",regex=True)
df.loc[df.toes.str.match(pattern2)==True]=df.loc[df.toes.str.match(pattern2)==True].replace(" ","-",regex=True)
df.loc[df.toes.str.match(pattern3)==True]=df.loc[df.toes.str.match(pattern3)==True].replace("'","",regex=True)

# %% [markdown]
# Confirm that these patterns have been corrected

# %%
print("\nThere are {} toe marks with spaces surrounding hypens.".format(df.loc[df.toes.str.match(pattern1)==True].shape[0]))
print("\nThere are {} toe marks with spaces surrounding numbers.".format(df.loc[df.toes.str.match(pattern2)==True].shape[0]))
print("\nThere are {} toe marks with an ' preceeding the entry.".format(df.loc[df.toes.str.match(pattern3)==True].shape[0]))
# Out:
# There are 0 toe marks with spaces surrounding hypens.
#
# There are 0 toe marks with spaces surrounding numbers.
#
# There are 0 toe marks with an ' preceeding the entry.

# %% [markdown]
# ## Cleaning Sex column

# %%
print(df.sex.str.len().unique())# returns unique lengths of sex
df.sex=df.sex.str.strip()
print(df.sex.str.len().unique())
# Out:
# [1 3 2 5]
# [1 3 2 0 5]

# %% [markdown]
# ### Identify non "m" or "f" values and their frequencies

# %%
patterns_sex="m|f|NA"
non_matches=df.sex.loc[df.sex.str.match(patterns_sex)!=True]
print("\nThere are {} entries for sex which do not match the patterns {}:"\
      .format(non_matches.shape[0],patterns_sex.split("|")))
non_matches.value_counts()
# Out:
# There are 5412 entries for sex which do not match the patterns ['m', 'f', 'NA']:
# nan      5254
# juv       128
# ?          16
# ?f          6
# n           2
# adult       1
# [m]         1
# ?m          1
# unm         1
# ???         1
#             1
# Name: sex, dtype: int64

# %% [markdown]
# ### Identify values to convert to NA, m, or f

# %%
sex2NA=['adult','juv','nan']
sex2m=['unm']
df.loc[df.sex.isin(sex2NA)==True]
print(df.sex.loc[df.sex.isin(sex2NA)==True].count())
print(df.sex.loc[df.sex.isin(sex2m)==True].count())
# Out:
# 5383
# 1

# %% [markdown]
# ### Convert the values to NA or m, respectively.

# %%
df.loc[df.sex.isin(sex2m)]
# Out:
#      species toes       date  sex  svl  tl  rtl_orig  mass paint.mark  \
# 7726      up  NaN 2017-07-20  unm  NaN NaN       NaN   NaN        NaN
#
#                                 location        ...         review_painted  \
# 7726  3m above sb on rt side 4m ^ CC/CCC        ...                  False
#
#      review_new.recap review_rtl forceMale forceFemale  forceRecap  forceNew  \
# 7726             True      False     False       False       False     False
#
#       forceSighting drop_species drop_morphometrics
# 7726          False         True               True
#
# [1 rows x 32 columns]

# %%
df.loc[df.sex.isin(sex2NA),'sex']=np.nan
df.loc[df.sex.isin(sex2m),'sex']='m'
print(df.sex.loc[df.sex.isin(sex2NA)==True].count())
print(df.sex.loc[df.sex.isin(sex2m)==True].count())
# Out:
# 0
# 0

# %% [markdown]
# # Cleaning autotmized column

# %%
autotomyDict = {False:'intact',True:'autotomized'}

df.loc[:,'autotomized'] = df.loc[:,'autotomized'].map(autotomyDict)
df.autotomized.unique()
# Out:
# array(['intact', 'autotomized'], dtype=object)

# %% [markdown]
# # Cleaning new.recap column

# %%
df.head()
# Out:
#   species     toes       date sex   svl    tl  rtl_orig  mass paint.mark  \
# 0       j  1-13-19 2000-03-17   f  52.0  74.0       0.0   4.2        r1c
# 1       j  1-13-20 2000-03-17   m  56.0  77.0       0.0   5.6        r2c
# 2       j  1-14-19 2000-03-17   f  57.0  81.0       0.0   6.6        r3c
# 3       j  1-14-20 2000-03-17   f  57.0  79.0       0.0   5.5        r4c
# 4       j      3-8 2000-03-17   f  82.0  89.0      27.0  17.0        r5c
#
#                                    location        ...         review_painted  \
# 0                                    1falls        ...                  False
# 1                                    1falls        ...                  False
# 2       wall on rt side v wall at pine xing        ...                  False
# 3       wall on rt side v wall at pine xing        ...                  False
# 4  oak across from bottom wall at pine xing        ...                  False
#
#   review_new.recap review_rtl forceMale forceFemale  forceRecap  forceNew  \
# 0            False      False     False       False       False     False
# 1            False      False     False       False       False     False
# 2            False      False     False       False       False     False
# 3            False      False     False       False       False     False
# 4            False      False     False       False       False     False
#
#   forceSighting drop_species drop_morphometrics
# 0         False        False              False
# 1         False        False              False
# 2         False        False              False
# 3         False        False              False
# 4         False        False              False
#
# [5 rows x 32 columns]

# %%
#try using a dict to do thing more efficiently
newRecapKeep = ['recap', 'new', 'r', 'n']
new = ['new','n']
recap = ['recap','r']
df.loc[~df['new.recap'].isin(newRecapKeep),'new.recap'] = np.nan
df.loc[df['new.recap'].isin(new),'new.recap'] = 'new'
df.loc[df['new.recap'].isin(recap),'new.recap'] = 'recap'

# %% [markdown]
# ## Add Columns

# %%
# tl_svl and mass_svl
df['tl_svl']=(df.tl/df.svl)
df['mass_svl']=(df.mass/df.svl)

# %% [markdown]
# ## Create function to generate lizardNumber
#  lizard number is a numeric identifier of unique animals in the data set
# function takes the following arguments:
#     - *x*: series object on which function acts on
#     - *sortCriteria*: list of strings of column names on which to sort data.  data are sorted by columns from left to right
#     - *validationCriteria*: dictionary of dictionaries that identify columns to validate and validation expression of the form {{'column':'column_2 >= column_1'},{'otherColumn':'column_2 >= column_1'}}
#     - *result*: dictionary of of dictionaries detailing the value *x* takes if validations are True or False of the form: {{'True':x=x[i]},{'False':x=x[i]+1},{errors: 'raise'}}, errors may be 'raise' *default* (terminates function and returns an error) or 'ignore' (returns 'NA')
# Function action:
# - first sort data by species, toes, then date
#
# - for time points 1 and , with 2 being later:
#     - toes2 == toes1
#     - svl2-svl1 >=-2
#     - year2-year1 <=7
#     - for species ==j:
#         - if svl >=56:
#             - if sex2==sex1:
#                 lizardNumber[i+1]=lizardNumber[i]
#           else:
#             - lizardNumber[i+1]=lizardNumber[i]+1

# %%
import pandas as pd
import os
def genliznum2(df, path:str, errors:str= 'raise'):
    """
    Lizard number is a numeric identifier of unique animals in the data set function takes the following arguments:
    :param df:  series object on which function acts on
    :param sortCriteria: list of strings of column names on which to sort data.  data are sorted by columns from left \
    to right
    :param validation: dictionary of dictionaries that identify columns to validate and validation expression of the form:\
     {{'column':'column_2 >= column_1'},{'otherColumn':'column_2 >= column_1'}}
    :param errors: str , errors may be 'raise' *default* (terminates function and returns an error) or 'ignore' (returns 'NA')
    :return: dataframe
    #dictionary  of dictionaries detailing the value *x* takes if validations are True or False of the form: \
    #{{'True':x=x[i]},{'False':x=x[i]+1},{errors: 'raise'}}
    """
    sortCriteria = ['species','toes', 'sex']
    validation = ['date','svl']
    critical = sortCriteria +validation
    #identify lizards with sufficient data to evaluate
    #report on those without sufficient data and save them to a file for later evaluation
    unsortable = df.loc[df.loc[:,critical].isnull().any(axis=1)]
    sortable = df.loc[df.loc[:,critical].notnull().all(axis=1)]
    os.chdir(path)
    unsortablefile ='unsortable.csv'
    unsortable.to_csv(unsortablefile)
    print("\nThere were {} entries for which values for one of the critical criteria, ({}), were null.  These entries could \
not be evaluated and were written out to the file {} for evaluation."\
          .format(unsortable.shape[0],critical,unsortablefile))
    
    sortable_min_date =pd.DataFrame(sortable.groupby(sortCriteria).date.min()).\
    rename(index = str, columns= {'date':'earliestSighting'}).reset_index()
    sortable = sortable.merge(sortable_min_date,how = 'left', on = sortCriteria)
    sortable['year_diff'] = sortable.date.dt.year - sortable.earliestSighting.dt.year
    
    svlGroup = ['species','toes', 'sex','earliestSighting']
    

    sortable_smallest_svl =sortable.groupby(svlGroup).svl.min().reset_index()\
    .rename(index = str, columns= {'svl':'smallest_svl'})
    sortable_smallest_svl
    sortable = sortable.merge(sortable_smallest_svl,how = 'left', on = svlGroup)
    sortable['svl_diff'] = sortable.svl - sortable.smallest_svl
    
    #Now we create a dataframe containing potential lizard numbers, all of which are designated as unassigned
    dfLizNumber = pd.DataFrame(df.index +1).reset_index().rename(index = str, columns = {0:'lizard_number'})
    dfLizNumber['assignment_status'] = 'unassigned'
    dfLizNumber = dfLizNumber.loc[:, ['lizard_number','assignment_status']]

    # Now we 
    
    res = {'data':sortable,'numbers':dfLizNumber}
    return res

# %%
test_tmp = genliznum2(df,'C:\\Users\\Christopher\\Documents\\GitHub\\tailDemography\\data')

test = test_tmp['data']
test['tmp'] = 1

#test ['liznumber'] = np.nan

test
# Out:
# There were 5568 entries for which values for one of the critical criteria, (['species', 'toes', 'sex', 'date', 'svl']), were null.  These entries could not be evaluated and were written out to the file unsortable.csv for evaluation.
#      species       toes       date sex   svl     tl  rtl_orig  mass  \
# 0          j    1-13-19 2000-03-17   f  52.0   74.0       0.0   4.2
# 1          j    1-13-20 2000-03-17   m  56.0   77.0       0.0   5.6
# 2          j    1-14-19 2000-03-17   f  57.0   81.0       0.0   6.6
# 3          j    1-14-20 2000-03-17   f  57.0   79.0       0.0   5.5
# 4          j        3-8 2000-03-17   f  82.0   89.0      27.0  17.0
# 5          j    1-15-16 2000-03-17   m  58.0   64.0      24.0   5.5
# 6          j       1-18 2000-03-17   f  58.0   62.0      20.0   7.0
# 7          j    1-13-18 2000-03-17   f  54.0   75.0       0.0   5.5
# 8          j       1-19 2000-03-17   m  62.0   84.0       0.0   7.5
# 9          j       1-20 2000-03-17   f  60.0   80.0       0.0   8.0
# 10         j    3-14-17 2000-03-17   f  74.0   97.0       0.0  15.6
# 11         j    9-11-19 2000-03-17   f  60.0   79.0       0.0   7.5
# 12         j    9-11-20 2000-03-17   m  62.0   87.0       0.0   7.6
# 13         j  5-7-15-20 2000-03-17   f  65.0   86.0      18.0   8.4
# 14         j    1-11-19 2000-03-17   f  60.0   76.0       0.0   7.0
# 15         j  5-7-12-16 2000-03-17   m  82.0  118.0       0.0  14.2
# 16         j  5-9-15-18 2000-03-17   m  75.0   99.0       0.0  11.5
# 17         j    1-13-19 2000-03-17   f  53.0   69.0       0.0   5.0
# 18         j    9-12-19 2000-03-17   m  72.0  101.0       0.0   9.8
# 19         j    9-12-20 2000-03-17   f  56.0   74.0       0.0   6.4
# 20         j    9-13-19 2000-03-17   f  50.0   71.0       0.0   5.5
# 21         j  5-6-13-20 2000-03-17   f  67.0   88.0       0.0   9.8
# 22         j    9-13-20 2000-03-17   m  62.0   85.0       0.0   6.6
# 23         j    9-14-19 2000-03-17   m  70.0   98.0       0.0   8.5
# 24         j    9-14-20 2000-03-17   m  64.0   74.0      25.0   7.3
# 25         j    4-14-20 2000-03-17   f  78.0   77.0      20.0  14.3
# 26         j  1-9-13-16 2000-03-18   f  50.0   76.0       0.0   6.5
# 27         j    9-15-19 2000-03-18   f  50.0   72.0       0.0   3.8
# 28         j        1-7 2000-03-18   m  84.0   45.0      29.0  18.2
# 29         j    9-15-20 2000-03-18   f  51.0   65.0       0.0   3.8
# ...      ...        ...        ...  ..   ...    ...       ...   ...
# 2599       j      12-20 2017-07-26   f  42.0   58.0       0.0   2.2
# 2600       j      13-16 2017-07-26   f  47.0   65.0       0.0   3.4
# 2601       j      13-17 2017-07-26   f  46.0   66.0       0.0   3.0
# 2602       j      13-18 2017-07-26   m  44.0   59.0       0.0   2.8
# 2603       j     5-9-20 2017-07-26   f  73.0  102.0       0.0  15.3
# 2604       v     4-9-15 2017-07-26   f  61.0   76.0       0.0   7.3
# 2605       v     2-8-16 2017-07-26   m  51.0   67.0       0.0   4.8
# 2606       j      13-19 2017-07-27   m  51.0   69.0       0.0   4.3
# 2607       v     2-8-17 2017-07-27   m  51.0   71.0       0.0   4.4
# 2608       j      13-20 2017-07-27   f  44.0   59.0       0.0   2.8
# 2609       j      14-20 2017-07-27   f  46.0   68.0       0.0   3.3
# 2610       j      14-17 2017-07-27   f  50.0   68.0       0.0   4.3
# 2611       j      14-16 2017-07-27   m  38.0   69.0       0.0   3.8
# 2612       j      14-19 2017-07-28   f  44.0   64.0       0.0   2.8
# 2613       j      14-18 2017-07-28   f  50.0   68.0       0.0   3.6
# 2614       j   10-14-16 2017-07-28   m  79.0  111.0       0.0  16.3
# 2615       j    8-15-18 2017-07-29   m  49.0   65.0       0.0   3.4
# 2616       v     2-8-18 2017-07-29   ?  54.0   70.0       0.0   5.4
# 2617       j   10-14-17 2017-07-29   m  82.0  115.0       0.0  19.0
# 2618       j   10-14-18 2017-07-29   f  79.0   88.0       3.0  11.5
# 2619       j      14-20 2017-07-30   m  50.0   66.0       0.0   4.2
# 2620       j      12-19 2017-07-31   f  46.0   65.0       0.0   2.9
# 2621       j      15-16 2017-07-31   f  42.0   57.0       0.0   2.3
# 2622       j      15-17 2017-07-31   f  43.0   59.0       6.0   2.6
# 2623       j      15-18 2017-07-31   m  43.0   57.0       0.0   2.4
# 2624       j      15-19 2017-08-01   m  55.0   75.0       0.0   5.2
# 2625       j      15-20 2017-08-02   m  50.0   65.0       0.0   NaN
# 2626       j       9-11 2017-08-02   f  45.0   58.0       0.0   2.9
# 2627       j       9-12 2017-08-02   f  48.0   65.0       0.0   3.2
# 2628       j       9-13 2017-08-02   m  47.0   63.0       0.0   3.6
#
#      paint.mark                                      location ...  \
# 0           r1c                                        1falls ...
# 1           r2c                                        1falls ...
# 2           r3c           wall on rt side v wall at pine xing ...
# 3           r4c           wall on rt side v wall at pine xing ...
# 4           r5c      oak across from bottom wall at pine xing ...
# 5           r6c  sb half way up from bottom wall to pine xing ...
# 6           r7c   sb 3/4 way up from bottom wall to pine xing ...
# 7           r8c                               sb at pine xing ...
# 8           r9c                            sb 10m ^ root xing ...
# 9          r10c                                      sb at H3 ...
# 10         r11c                                        1falls ...
# 11         r12c                     R wall on rt v cave trail ...
# 12         r13c     stump opp wall v bottom wall at pine xing ...
# 13         r14c  sb half way up from bottom wall to pine xing ...
# 14         r15c                       T crossing sb at CC/CCC ...
# 15         r16c                                        CC/CCC ...
# 16         r17c                                          slab ...
# 17         r18c                                   Rs opp slab ...
# 18         r19c                                   Rs opp slab ...
# 19         r20c                3m v oakR opp side from pine R ...
# 20         r22c                                  Rs opp pineR ...
# 21         r21c                                  Rs opp pineR ...
# 22         r23c                                  Rs opp pineR ...
# 23         r24c                                  Rs opp pineR ...
# 24         r25c                                        2falls ...
# 25     o.t/r26c                                            H5 ...
# 26         r27c                                    wall at H5 ...
# 27         r28c                                        CC/CCC ...
# 28         r29c                                        CC/CCC ...
# 29         r30c                   big stump just above CC/CCC ...
# ...         ...                                           ... ...
# 2599     w||b.t                                    top 1falls ...
# 2600       w||c                     4m up cave trail creekbed ...
# 2601        w:a                             rt side top chute ...
# 2602        w:b                          sb at blackR ^ 1oakR ...
# 2603     w13b|t                           left Rs 6m ^ 2falls ...
# 2604       w28c                                sb 10m v trail ...
# 2605       w29c                                sb 10m v trail ...
# 2606     w:c.rr                  top curved wall v cave trail ...
# 2607       w30c                                 sb mid w v jx ...
# 2608       w^^a                             sb 10m ^ 1tripleR ...
# 2609       w^^b               sb left side off blackR ^ 1oakR ...
# 2610       wvva                                    sb at slab ...
# 2611       w^^c                                left Rs 2falls ...
# 2612     wvvc.t                          sb 3m v bottom chute ...
# 2613       wvvb                               R sb at fox den ...
# 2614       w35v                                     mid chute ...
# 2615        w+c                          w v w v juniper xing ...
# 2616       w32c                            Rs sb 2m^root xing ...
# 2617       w38b                                      pyramidR ...
# 2618       w39b                                      pyramidR ...
# 2619       w++c                                  sb 8m ^ slab ...
# 2620       w++b                             left sb 8m^1falls ...
# 2621       w++c                              Rs sb 5m v pineR ...
# 2622        woa                                   slab v slab ...
# 2623        wob                       R sb at T ^ entry trail ...
# 2624        woc                  R left sb 2m v and opp pineR ...
# 2625        w.t                                sb at pyramidR ...
# 2626      w..|t                                  sb mid talus ...
# 2627        w|t                                           sb  ...
# 2628        w-t                           sb very bottom site ...
#
#      forceSighting drop_species drop_morphometrics    tl_svl  mass_svl  \
# 0            False        False              False  1.423077  0.080769
# 1            False        False              False  1.375000  0.100000
# 2            False        False              False  1.421053  0.115789
# 3            False        False              False  1.385965  0.096491
# 4            False        False              False  1.085366  0.207317
# 5            False        False              False  1.103448  0.094828
# 6            False        False              False  1.068966  0.120690
# 7            False        False              False  1.388889  0.101852
# 8            False        False              False  1.354839  0.120968
# 9            False        False              False  1.333333  0.133333
# 10           False        False              False  1.310811  0.210811
# 11           False        False              False  1.316667  0.125000
# 12           False        False              False  1.403226  0.122581
# 13           False        False              False  1.323077  0.129231
# 14           False        False              False  1.266667  0.116667
# 15           False        False              False  1.439024  0.173171
# 16           False        False              False  1.320000  0.153333
# 17           False        False              False  1.301887  0.094340
# 18           False        False              False  1.402778  0.136111
# 19           False        False              False  1.321429  0.114286
# 20           False        False              False  1.420000  0.110000
# 21           False        False              False  1.313433  0.146269
# 22           False        False              False  1.370968  0.106452
# 23           False        False              False  1.400000  0.121429
# 24           False        False              False  1.156250  0.114062
# 25           False        False              False  0.987179  0.183333
# 26           False        False              False  1.520000  0.130000
# 27           False        False              False  1.440000  0.076000
# 28           False        False              False  0.535714  0.216667
# 29           False        False              False  1.274510  0.074510
# ...            ...          ...                ...       ...       ...
# 2599         False        False              False  1.380952  0.052381
# 2600         False        False              False  1.382979  0.072340
# 2601         False        False              False  1.434783  0.065217
# 2602         False        False              False  1.340909  0.063636
# 2603         False        False              False  1.397260  0.209589
# 2604         False        False              False  1.245902  0.119672
# 2605         False        False              False  1.313725  0.094118
# 2606         False        False              False  1.352941  0.084314
# 2607         False        False              False  1.392157  0.086275
# 2608         False        False              False  1.340909  0.063636
# 2609         False        False              False  1.478261  0.071739
# 2610         False        False              False  1.360000  0.086000
# 2611         False        False              False  1.815789  0.100000
# 2612         False        False              False  1.454545  0.063636
# 2613         False        False              False  1.360000  0.072000
# 2614         False        False              False  1.405063  0.206329
# 2615         False        False              False  1.326531  0.069388
# 2616         False        False              False  1.296296  0.100000
# 2617         False        False              False  1.402439  0.231707
# 2618         False        False              False  1.113924  0.145570
# 2619         False        False              False  1.320000  0.084000
# 2620         False        False              False  1.413043  0.063043
# 2621         False        False              False  1.357143  0.054762
# 2622         False        False              False  1.372093  0.060465
# 2623         False        False              False  1.325581  0.055814
# 2624         False        False              False  1.363636  0.094545
# 2625         False        False              False  1.300000       NaN
# 2626         False        False              False  1.288889  0.064444
# 2627         False        False              False  1.354167  0.066667
# 2628         False        False              False  1.340426  0.076596
#
#       earliestSighting  year_diff smallest_svl svl_diff tmp
# 0           2000-03-17          0         52.0      0.0   1
# 1           2000-03-17          0         56.0      0.0   1
# 2           2000-03-17          0         57.0      0.0   1
# 3           2000-03-17          0         57.0      0.0   1
# 4           2000-03-17          0         82.0      0.0   1
# 5           2000-03-17          0         58.0      0.0   1
# 6           2000-03-17          0         58.0      0.0   1
# 7           2000-03-17          0         54.0      0.0   1
# 8           2000-03-17          0         62.0      0.0   1
# 9           2000-03-17          0         27.0     33.0   1
# 10          2000-03-17          0         74.0      0.0   1
# 11          2000-03-17          0         60.0      0.0   1
# 12          2000-03-17          0         62.0      0.0   1
# 13          2000-03-17          0         65.0      0.0   1
# 14          2000-03-17          0         60.0      0.0   1
# 15          2000-03-17          0         82.0      0.0   1
# 16          2000-03-17          0         75.0      0.0   1
# 17          2000-03-17          0         52.0      1.0   1
# 18          2000-03-17          0         72.0      0.0   1
# 19          2000-03-17          0         56.0      0.0   1
# 20          2000-03-17          0         50.0      0.0   1
# 21          2000-03-17          0         67.0      0.0   1
# 22          2000-03-17          0         62.0      0.0   1
# 23          2000-03-17          0         70.0      0.0   1
# 24          2000-03-17          0         64.0      0.0   1
# 25          2000-03-17          0         78.0      0.0   1
# 26          2000-03-18          0         50.0      0.0   1
# 27          2000-03-18          0         50.0      0.0   1
# 28          2000-03-18          0         84.0      0.0   1
# 29          2000-03-18          0         51.0      0.0   1
# ...                ...        ...          ...      ...  ..
# 2599        2007-07-06         10         36.0      6.0   1
# 2600        2007-07-06         10         37.0     10.0   1
# 2601        2017-07-26          0         46.0      0.0   1
# 2602        2017-07-26          0         44.0      0.0   1
# 2603        2016-05-05          1         63.0     10.0   1
# 2604        2005-07-04         12         47.0     14.0   1
# 2605        2017-07-26          0         51.0      0.0   1
# 2606        2007-07-07         10         40.0     11.0   1
# 2607        2017-07-27          0         51.0      0.0   1
# 2608        2017-07-27          0         44.0      0.0   1
# 2609        2007-07-09         10         32.0     14.0   1
# 2610        2017-07-27          0         50.0      0.0   1
# 2611        2007-07-08         10         33.0      5.0   1
# 2612        2007-07-09         10         35.0      9.0   1
# 2613        2017-07-28          0         50.0      0.0   1
# 2614        2017-07-28          0         79.0      0.0   1
# 2615        2017-07-24          0         46.0      3.0   1
# 2616        2017-07-29          0         54.0      0.0   1
# 2617        2017-07-29          0         82.0      0.0   1
# 2618        2017-07-29          0         79.0      0.0   1
# 2619        2017-07-30          0         50.0      0.0   1
# 2620        2017-07-25          0         45.0      1.0   1
# 2621        2017-07-31          0         42.0      0.0   1
# 2622        2017-07-31          0         43.0      0.0   1
# 2623        2007-07-13         10         39.0      4.0   1
# 2624        2007-07-13         10         35.0     20.0   1
# 2625        2017-08-02          0         50.0      0.0   1
# 2626        2017-08-02          0         45.0      0.0   1
# 2627        2017-08-02          0         48.0      0.0   1
# 2628        2017-08-02          0         47.0      0.0   1
#
# [2629 rows x 39 columns]

# %%
print(test.loc[(test.year_diff<=7) & (test.svl_diff>=-2),:].tmp.unique())
print(len(test.loc[(test.year_diff<=7) & (test.svl_diff>=-2),:].groupby(['species','sex','toes'])))
numbers = test.loc[(test.year_diff<=7) & (test.svl_diff>=-2),:].groupby(['species','sex','toes']).tmp.min().cumsum()\
.reset_index()
numbers = numbers.rename(columns={'tmp':'liznumber'})
numbers
# Out:
# [1]
# 1593
#      species  sex        toes  liznumber
# 0      cn ex    f         1-7          1
# 1      cn ex    f           7          2
# 2          j        3-6-13-16          3
# 3          j    ?   1-9-13-19          4
# 4          j    ?       11-18          5
# 5          j    ?       12-16          6
# 6          j    ?       14-18          7
# 7          j    ?   2-13-17 a          8
# 8          j    ?      2-8-13          9
# 9          j    ?   3-7-12-20         10
# 10         j  [m]   3-6-15-16         11
# 11         j    f  1-10-11-17         12
# 12         j    f  1-10-11-19         13
# 13         j    f  1-10-11-20         14
# 14         j    f  1-10-12-16         15
# 15         j    f  1-10-12-18         16
# 16         j    f  1-10-12-19         17
# 17         j    f  1-10-12-20         18
# 18         j    f  1-10-13-18         19
# 19         j    f  1-10-13-20         20
# 20         j    f  1-10-14-16         21
# 21         j    f  1-10-14-18         22
# 22         j    f  1-10-14-19         23
# 23         j    f  1-10-14-20         24
# 24         j    f  1-10-15-20         25
# 25         j    f     1-10-17         26
# 26         j    f    1-10-17a         27
# 27         j    f     1-10-19         28
# 28         j    f    1-11-17a         29
# 29         j    f     1-11-19         30
# ...      ...  ...         ...        ...
# 1563       v    m     7-14-17       1564
# 1564       v    m     7-15-16       1565
# 1565       v    m     7-15-19       1566
# 1566       v    m         7-9       1567
# 1567       v    m     8-11-17       1568
# 1568       v    m     8-11-19       1569
# 1569       v    m     8-11-20       1570
# 1570       v    m  8-12-13-14       1571
# 1571       v    m     8-12-16       1572
# 1572       v    m     8-12-17       1573
# 1573       v    m     8-12-18       1574
# 1574       v    m  8-13-15-20       1575
# 1575       v    m     8-13-16       1576
# 1576       v    m     8-13-18       1577
# 1577       v    m     8-13-19       1578
# 1578       v    m     8-13-20       1579
# 1579       v    m     8-14-16       1580
# 1580       v    m     8-14-19       1581
# 1581       v    m     8-14-20       1582
# 1582       v    m     8-15-16       1583
# 1583       v    m     8-15-18       1584
# 1584       v    m     8-15-19       1585
# 1585       v    m     9-11-16       1586
# 1586       v    m     9-11-18       1587
# 1587       v    m     9-11-20       1588
# 1588       v    m        9-13       1589
# 1589       v    m        9-16       1590
# 1590       v    m        9-19       1591
# 1591       v    m        9-20       1592
# 1592       v    n     3-12-16       1593
#
# [1593 rows x 4 columns]

# %%
test = test.merge(numbers,'left', on = ['species','sex','toes'])
test
# Out:
#      species       toes       date sex   svl     tl  rtl_orig  mass  \
# 0          j    1-13-19 2000-03-17   f  52.0   74.0       0.0   4.2
# 1          j    1-13-20 2000-03-17   m  56.0   77.0       0.0   5.6
# 2          j    1-14-19 2000-03-17   f  57.0   81.0       0.0   6.6
# 3          j    1-14-20 2000-03-17   f  57.0   79.0       0.0   5.5
# 4          j        3-8 2000-03-17   f  82.0   89.0      27.0  17.0
# 5          j    1-15-16 2000-03-17   m  58.0   64.0      24.0   5.5
# 6          j       1-18 2000-03-17   f  58.0   62.0      20.0   7.0
# 7          j    1-13-18 2000-03-17   f  54.0   75.0       0.0   5.5
# 8          j       1-19 2000-03-17   m  62.0   84.0       0.0   7.5
# 9          j       1-20 2000-03-17   f  60.0   80.0       0.0   8.0
# 10         j    3-14-17 2000-03-17   f  74.0   97.0       0.0  15.6
# 11         j    9-11-19 2000-03-17   f  60.0   79.0       0.0   7.5
# 12         j    9-11-20 2000-03-17   m  62.0   87.0       0.0   7.6
# 13         j  5-7-15-20 2000-03-17   f  65.0   86.0      18.0   8.4
# 14         j    1-11-19 2000-03-17   f  60.0   76.0       0.0   7.0
# 15         j  5-7-12-16 2000-03-17   m  82.0  118.0       0.0  14.2
# 16         j  5-9-15-18 2000-03-17   m  75.0   99.0       0.0  11.5
# 17         j    1-13-19 2000-03-17   f  53.0   69.0       0.0   5.0
# 18         j    9-12-19 2000-03-17   m  72.0  101.0       0.0   9.8
# 19         j    9-12-20 2000-03-17   f  56.0   74.0       0.0   6.4
# 20         j    9-13-19 2000-03-17   f  50.0   71.0       0.0   5.5
# 21         j  5-6-13-20 2000-03-17   f  67.0   88.0       0.0   9.8
# 22         j    9-13-20 2000-03-17   m  62.0   85.0       0.0   6.6
# 23         j    9-14-19 2000-03-17   m  70.0   98.0       0.0   8.5
# 24         j    9-14-20 2000-03-17   m  64.0   74.0      25.0   7.3
# 25         j    4-14-20 2000-03-17   f  78.0   77.0      20.0  14.3
# 26         j  1-9-13-16 2000-03-18   f  50.0   76.0       0.0   6.5
# 27         j    9-15-19 2000-03-18   f  50.0   72.0       0.0   3.8
# 28         j        1-7 2000-03-18   m  84.0   45.0      29.0  18.2
# 29         j    9-15-20 2000-03-18   f  51.0   65.0       0.0   3.8
# ...      ...        ...        ...  ..   ...    ...       ...   ...
# 2599       j      12-20 2017-07-26   f  42.0   58.0       0.0   2.2
# 2600       j      13-16 2017-07-26   f  47.0   65.0       0.0   3.4
# 2601       j      13-17 2017-07-26   f  46.0   66.0       0.0   3.0
# 2602       j      13-18 2017-07-26   m  44.0   59.0       0.0   2.8
# 2603       j     5-9-20 2017-07-26   f  73.0  102.0       0.0  15.3
# 2604       v     4-9-15 2017-07-26   f  61.0   76.0       0.0   7.3
# 2605       v     2-8-16 2017-07-26   m  51.0   67.0       0.0   4.8
# 2606       j      13-19 2017-07-27   m  51.0   69.0       0.0   4.3
# 2607       v     2-8-17 2017-07-27   m  51.0   71.0       0.0   4.4
# 2608       j      13-20 2017-07-27   f  44.0   59.0       0.0   2.8
# 2609       j      14-20 2017-07-27   f  46.0   68.0       0.0   3.3
# 2610       j      14-17 2017-07-27   f  50.0   68.0       0.0   4.3
# 2611       j      14-16 2017-07-27   m  38.0   69.0       0.0   3.8
# 2612       j      14-19 2017-07-28   f  44.0   64.0       0.0   2.8
# 2613       j      14-18 2017-07-28   f  50.0   68.0       0.0   3.6
# 2614       j   10-14-16 2017-07-28   m  79.0  111.0       0.0  16.3
# 2615       j    8-15-18 2017-07-29   m  49.0   65.0       0.0   3.4
# 2616       v     2-8-18 2017-07-29   ?  54.0   70.0       0.0   5.4
# 2617       j   10-14-17 2017-07-29   m  82.0  115.0       0.0  19.0
# 2618       j   10-14-18 2017-07-29   f  79.0   88.0       3.0  11.5
# 2619       j      14-20 2017-07-30   m  50.0   66.0       0.0   4.2
# 2620       j      12-19 2017-07-31   f  46.0   65.0       0.0   2.9
# 2621       j      15-16 2017-07-31   f  42.0   57.0       0.0   2.3
# 2622       j      15-17 2017-07-31   f  43.0   59.0       6.0   2.6
# 2623       j      15-18 2017-07-31   m  43.0   57.0       0.0   2.4
# 2624       j      15-19 2017-08-01   m  55.0   75.0       0.0   5.2
# 2625       j      15-20 2017-08-02   m  50.0   65.0       0.0   NaN
# 2626       j       9-11 2017-08-02   f  45.0   58.0       0.0   2.9
# 2627       j       9-12 2017-08-02   f  48.0   65.0       0.0   3.2
# 2628       j       9-13 2017-08-02   m  47.0   63.0       0.0   3.6
#
#      paint.mark                                      location    ...     \
# 0           r1c                                        1falls    ...
# 1           r2c                                        1falls    ...
# 2           r3c           wall on rt side v wall at pine xing    ...
# 3           r4c           wall on rt side v wall at pine xing    ...
# 4           r5c      oak across from bottom wall at pine xing    ...
# 5           r6c  sb half way up from bottom wall to pine xing    ...
# 6           r7c   sb 3/4 way up from bottom wall to pine xing    ...
# 7           r8c                               sb at pine xing    ...
# 8           r9c                            sb 10m ^ root xing    ...
# 9          r10c                                      sb at H3    ...
# 10         r11c                                        1falls    ...
# 11         r12c                     R wall on rt v cave trail    ...
# 12         r13c     stump opp wall v bottom wall at pine xing    ...
# 13         r14c  sb half way up from bottom wall to pine xing    ...
# 14         r15c                       T crossing sb at CC/CCC    ...
# 15         r16c                                        CC/CCC    ...
# 16         r17c                                          slab    ...
# 17         r18c                                   Rs opp slab    ...
# 18         r19c                                   Rs opp slab    ...
# 19         r20c                3m v oakR opp side from pine R    ...
# 20         r22c                                  Rs opp pineR    ...
# 21         r21c                                  Rs opp pineR    ...
# 22         r23c                                  Rs opp pineR    ...
# 23         r24c                                  Rs opp pineR    ...
# 24         r25c                                        2falls    ...
# 25     o.t/r26c                                            H5    ...
# 26         r27c                                    wall at H5    ...
# 27         r28c                                        CC/CCC    ...
# 28         r29c                                        CC/CCC    ...
# 29         r30c                   big stump just above CC/CCC    ...
# ...         ...                                           ...    ...
# 2599     w||b.t                                    top 1falls    ...
# 2600       w||c                     4m up cave trail creekbed    ...
# 2601        w:a                             rt side top chute    ...
# 2602        w:b                          sb at blackR ^ 1oakR    ...
# 2603     w13b|t                           left Rs 6m ^ 2falls    ...
# 2604       w28c                                sb 10m v trail    ...
# 2605       w29c                                sb 10m v trail    ...
# 2606     w:c.rr                  top curved wall v cave trail    ...
# 2607       w30c                                 sb mid w v jx    ...
# 2608       w^^a                             sb 10m ^ 1tripleR    ...
# 2609       w^^b               sb left side off blackR ^ 1oakR    ...
# 2610       wvva                                    sb at slab    ...
# 2611       w^^c                                left Rs 2falls    ...
# 2612     wvvc.t                          sb 3m v bottom chute    ...
# 2613       wvvb                               R sb at fox den    ...
# 2614       w35v                                     mid chute    ...
# 2615        w+c                          w v w v juniper xing    ...
# 2616       w32c                            Rs sb 2m^root xing    ...
# 2617       w38b                                      pyramidR    ...
# 2618       w39b                                      pyramidR    ...
# 2619       w++c                                  sb 8m ^ slab    ...
# 2620       w++b                             left sb 8m^1falls    ...
# 2621       w++c                              Rs sb 5m v pineR    ...
# 2622        woa                                   slab v slab    ...
# 2623        wob                       R sb at T ^ entry trail    ...
# 2624        woc                  R left sb 2m v and opp pineR    ...
# 2625        w.t                                sb at pyramidR    ...
# 2626      w..|t                                  sb mid talus    ...
# 2627        w|t                                           sb     ...
# 2628        w-t                           sb very bottom site    ...
#
#      earliestSighting year_diff smallest_svl svl_diff tmp liznumber_x  \
# 0          2000-03-17         0         52.0      0.0   1          45
# 1          2000-03-17         0         56.0      0.0   1         562
# 2          2000-03-17         0         57.0      0.0   1          52
# 3          2000-03-17         0         57.0      0.0   1          53
# 4          2000-03-17         0         82.0      0.0   1         285
# 5          2000-03-17         0         58.0      0.0   1         568
# 6          2000-03-17         0         58.0      0.0   1          57
# 7          2000-03-17         0         54.0      0.0   1          43
# 8          2000-03-17         0         62.0      0.0   1         575
# 9          2000-03-17         0         27.0     33.0   1          61
# 10         2000-03-17         0         74.0      0.0   1         265
# 11         2000-03-17         0         60.0      0.0   1         513
# 12         2000-03-17         0         62.0      0.0   1         974
# 13         2000-03-17         0         65.0      0.0   1         436
# 14         2000-03-17         0         60.0      0.0   1          30
# 15         2000-03-17         0         82.0      0.0   1         879
# 16         2000-03-17         0         75.0      0.0   1         914
# 17         2000-03-17         0         52.0      1.0   1          45
# 18         2000-03-17         0         72.0      0.0   1         975
# 19         2000-03-17         0         56.0      0.0   1         515
# 20         2000-03-17         0         50.0      0.0   1         516
# 21         2000-03-17         0         67.0      0.0   1         412
# 22         2000-03-17         0         62.0      0.0   1         977
# 23         2000-03-17         0         70.0      0.0   1         978
# 24         2000-03-17         0         64.0      0.0   1         979
# 25         2000-03-17         0         78.0      0.0   1         340
# 26         2000-03-18         0         50.0      0.0   1         102
# 27         2000-03-18         0         50.0      0.0   1         517
# 28         2000-03-18         0         84.0      0.0   1         586
# 29         2000-03-18         0         51.0      0.0   1         518
# ...               ...       ...          ...      ...  ..         ...
# 2599       2007-07-06        10         36.0      6.0   1         141
# 2600       2007-07-06        10         37.0     10.0   1         143
# 2601       2017-07-26         0         46.0      0.0   1         144
# 2602       2017-07-26         0         44.0      0.0   1         643
# 2603       2016-05-05         1         63.0     10.0   1         456
# 2604       2005-07-04        12         47.0     14.0   1        1286
# 2605       2017-07-26         0         51.0      0.0   1        1426
# 2606       2007-07-07        10         40.0     11.0   1         644
# 2607       2017-07-27         0         51.0      0.0   1        1427
# 2608       2017-07-27         0         44.0      0.0   1         146
# 2609       2007-07-09        10         32.0     14.0   1         151
# 2610       2017-07-27         0         50.0      0.0   1         148
# 2611       2007-07-08        10         33.0      5.0   1         646
# 2612       2007-07-09        10         35.0      9.0   1         150
# 2613       2017-07-28         0         50.0      0.0   1         149
# 2614       2017-07-28         0         79.0      0.0   1         631
# 2615       2017-07-24         0         46.0      3.0   1         970
# 2616       2017-07-29         0         54.0      0.0   1        1148
# 2617       2017-07-29         0         82.0      0.0   1         632
# 2618       2017-07-29         0         79.0      0.0   1         121
# 2619       2017-07-30         0         50.0      0.0   1         648
# 2620       2017-07-25         0         45.0      1.0   1         140
# 2621       2017-07-31         0         42.0      0.0   1         153
# 2622       2017-07-31         0         43.0      0.0   1         154
# 2623       2007-07-13        10         39.0      4.0   1         651
# 2624       2007-07-13        10         35.0     20.0   1         652
# 2625       2017-08-02         0         50.0      0.0   1         653
# 2626       2017-08-02         0         45.0      0.0   1         512
# 2627       2017-08-02         0         48.0      0.0   1         514
# 2628       2017-08-02         0         47.0      0.0   1         976
#
#      liznumber_y liznumber_x liznumber_y liznumber
# 0             45          45          45        45
# 1            562         562         562       562
# 2             52          52          52        52
# 3             53          53          53        53
# 4            285         285         285       285
# 5            568         568         568       568
# 6             57          57          57        57
# 7             43          43          43        43
# 8            575         575         575       575
# 9             61          61          61        61
# 10           265         265         265       265
# 11           513         513         513       513
# 12           974         974         974       974
# 13           436         436         436       436
# 14            30          30          30        30
# 15           879         879         879       879
# 16           914         914         914       914
# 17            45          45          45        45
# 18           975         975         975       975
# 19           515         515         515       515
# 20           516         516         516       516
# 21           412         412         412       412
# 22           977         977         977       977
# 23           978         978         978       978
# 24           979         979         979       979
# 25           340         340         340       340
# 26           102         102         102       102
# 27           517         517         517       517
# 28           586         586         586       586
# 29           518         518         518       518
# ...          ...         ...         ...       ...
# 2599         141         141         141       141
# 2600         143         143         143       143
# 2601         144         144         144       144
# 2602         643         643         643       643
# 2603         456         456         456       456
# 2604        1286        1286        1286      1286
# 2605        1426        1426        1426      1426
# 2606         644         644         644       644
# 2607        1427        1427        1427      1427
# 2608         146         146         146       146
# 2609         151         151         151       151
# 2610         148         148         148       148
# 2611         646         646         646       646
# 2612         150         150         150       150
# 2613         149         149         149       149
# 2614         631         631         631       631
# 2615         970         970         970       970
# 2616        1148        1148        1148      1148
# 2617         632         632         632       632
# 2618         121         121         121       121
# 2619         648         648         648       648
# 2620         140         140         140       140
# 2621         153         153         153       153
# 2622         154         154         154       154
# 2623         651         651         651       651
# 2624         652         652         652       652
# 2625         653         653         653       653
# 2626         512         512         512       512
# 2627         514         514         514       514
# 2628         976         976         976       976
#
# [2629 rows x 44 columns]

# %%
#test['earliestSighting'] = np.nan
svlGroup = ['species','toes', 'sex','earliestSighting']
test_smallest_svl = pd.DataFrame(test.groupby(svlGroup).svl.min()).rename(index = str, columns= {'svl':'smallest_svl'})\
.reset_index()
test_smallest_svl
#test

test.merge(test_smallest_svl,how = 'left', on = svlGroup).smallest_svl.unique()
#test.head()

# %%
test['dateMin'] = test.groupby(sortCriteria).date.min()

# %%
print('The qc output of gen_liz_num(df) shows that {} rows in the df dataframe could not be processed. \nOf these, \
{} did not contain information on species, toes, and sex. \n{} did not contain information on either toes or sex.\n\
{} did not contain information on both toes and sex. \n{} did not not contain information on sex, but contained\
 information on toes. \n{} did not not contain information on toes, but contained\
 information on sex.'\
      .format(qc.shape[0],qc.loc[(qc.species.isnull()) & (qc.toes.isnull()) & (qc.sex.isnull()),:].shape[0]\
                                                             ,qc.loc[(qc.toes.isnull())|(qc.sex.isnull()),:].shape[0]\
                                                             ,qc.loc[(qc.toes.isnull()) & (qc.sex.isnull()),:].shape[0]\
             ,qc.loc[(qc.toes.notnull()) & (qc.sex.isnull()),:].shape[0]\
             ,qc.loc[(qc.toes.isnull()) & (qc.sex.notnull()),:].shape[0]))
print('\n Of the above, {} had paintmarks which we might be used to attempt to recover data.\
\nOf those in the dataframe without a lizNumber, {} had paintmarks which we might be used to attempt to recover data.'\
      .format(df.loc[(df['paint.mark'].notnull()) & (df.lizMark.isnull()),:].shape[0],\
             df.loc[(df['paint.mark'].notnull()) & (df.lizNumber.isnull()),:].shape[0]))
qc.head(3)

# %% [markdown]
# We can see from the output of the last chunk that the function is operating as expected.  The data that weren't assigned a lizard number cannot be assigned one and should probably be removed from analyses that cross years.  We can try to

# %% [markdown]
# # NOTE:
# - _unprocessed_ still needs to be manually entered

# %%
df.lizNumber.min()
df.lizNumber.max()

# %%
possibleLizNum = set(range(int(df.lizNumber.min()),int(df.lizNumber.max())))
actualLizNum = set(pd.Series(df.lizNumber.unique()).dropna().apply(int))
missingLizNum = possibleLizNum - actualLizNum

print("\nThere are {} entries.  There are {} unique lizard numbers.\
\n\nThe lizNumber ranges from {} to {}.\
\n\nThe following numbers are not assigned to a lizard:\n{}"\
      .format(df.shape[0],len(df.lizNumber.unique())\
              ,df.lizNumber.min(),df.lizNumber.max(),missingLizNum))

# %% [markdown]
# Now we export the cleaned data to a csv

# %%
df = df.rename(index = str, columns = {'new.recap':'newRecap'})

# %%
timestamp = pd.to_datetime('now')-pd.Timedelta(hours=5)
#path=''C:\\Users\\Christopher\\Google Drive\\TailDemography\\outputFiles\\''
path='C:\\Users\\Christopher\\Google Drive\\TailDemography\\outputFiles\\'
#filename = path + 'cleaned CC data 2000-2017_' + str(timestamp)+ '.csv'
filename = path + 'cleaned CC data 2000-2017_' + '.csv'
df.to_csv(filename,index = False)
filename

# %%
df.groupby('lizardNumber').species.count()
